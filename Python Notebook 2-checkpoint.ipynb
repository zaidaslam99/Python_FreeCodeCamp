# %%
# This program lets the user enter a course number and then it displays the course number, instructor and
    # and meeting time

# Start off by getting the course number and their instructor and meeting times
    # and store them to a dict
uni_courses = {"CS101" : [3004, "Haynes", "8:00am"],
               "CS102" : [4501, "Alvarado", "9:00am"],
               "CS103" : [6755, "Rich", "10:00am"],
               "NT110" : [1244, "Burke", "11:00am"],
               "CM241" : [1411, "Lee", "1:00pm"]}

# Get the input from the user
user_input = input("Enter the course number and we will find out more details about your class: ")

# Set the while conditon
another = "Y"

while another.upper() == "Y":

    # Cap the user input
    user_input = user_input.upper()

    if user_input in uni_courses:
        room_number = uni_courses[user_input][0]
        teacher = uni_courses[user_input][1]
        time = uni_courses[user_input][2]

        print(f"Room number: {room_number}")
        print(f"Teacher: {teacher}")
        print(f"Time: {time}")

    else:
        print("Sorry that course is not in the list")

    another = input("Would you like to search for a different course? ")

    if another.upper() == "N":
        print("Ending the program")
    else:
        user_input = input("Enter the course number and we will find out more details about your class: ")


#________________________________________________________________________________________________
# SUMMARY:
    # So here in this code it was really simple to understand everything that was going on the thing that I had learned
        # in this code was the use of list within the dict now before we begin the first thing that I want to go over
        # is the concept when it comes to printing the key of a dict we are going to be saying dict[key] = value and
        # this was something that was printing the value now this was the first code where I worked with writting with
        # a dict so it was teaching how to use dicts now the first problem that I had was that I was thinking to myself
        # that how am I going to be storing the classroom the teacher the meeting time and the room number all in one
        # dict and the answer was really simple it was using a dict and then using a list within the dict now that was
        # something that we covered in the book but never really used in a problem the first thing that I was going to
        # do was that I was going to create separate dict for each class but the thing that I had realized here was that
        # when it comes to this was using a for loop when it comes to using a for loop the thing that goes wrong is that
        # we then are trying to loop through each different class and it becomes really hard to understand because the
        # thing gets really complicated here so then I decided here that I was going to be using the key : [] doing this
        # what I can do is for each key I can store multiple values now the problem was how am I going to be getting
        # the value of each key such as the classroom, the name and the time the next thing that I had done was that I
        # get the user input and then when it comes to the while loop we stated string control and then we had uppercase
        # the user input the next part is the conditonal statement when it comes to the user input this is something
        # that we are trying to search in this case its going to be the string and we are checking to see if the string
        # is in the dict so take a look at the next diagram below...
"""
        dict_test = {"key" : "value"}
        if "key" in dict_test:
            print(dict_test["key"])
"""
        # this is saying that we are making a dict and that is storing the key and the value and we are checking to see
        # if the key is in dict test this goes back to the logic where we are getting the user input as a string and
        # then checking it with our dict and it shows us how when we type in the string we can cross reference the key
        # value this is something that we learned but it shows how we can apply this knowledge so the logic that we
        # stated is that if the string is in the dict then do this now the prob that came to my mind was that how are we
        # going to access each element and print out each value and then I leanred from this code look below...
"""
        thisdict =	{
          "brand": "Ford",
          "model": "Mustang",
          "year": 1964
        }

        x = thisdict["model"]
        print(x)
"""
        # this code made things more clear notice what is happening here we are creating a dict that is storing the
        # brand the model and the year and then we saving the value of model to the variable x and the only way to 
        # access this variable is dict[key] but that was the lead that I had now the problem that I was having was that 
        # I was wondering that I knew that to get each room number, teacher, time I had to access these values somehow 
        # and here is how I did so...

"""
        room_number = uni_courses[user_input][0]
        teacher = uni_courses[user_input][1]
        time = uni_courses[user_input][2]
"""
        # I had the idea where I was like I know how list are index when it comes to zero indexing so then I thought
        # that maybe I can get the dict[user_input (in this case which class the user had chose)][index] so this is 
        # going to say uni_course["CS101"][0] in this case it is going to be the room number now to be honest this was 
        # something that I was like this may not work here but then when I had tried it then it had worked so I got 
        # lucky with it once I stored the room number teacher and time the thing I simply just printed the value the 
        # logic that I want to talk about here is that so we get the dict we get the key then get the specifc value this
        # code teaches us about value vs specific value and we print it for that code the rest of the code is self 
        # explanatory.

# %%
# This program creates a dict containing the US states as keys and their capitals as values. It then quiz the user
    # by displaying the name of a state and asking the user to enter the states capital. The program should keep a
    # count of the number of correct and incorrect responses.
import random

def main():

    state_and_capital_dict = get_state_and_capital()

    state_name_list = get_random_value_dict(state_and_capital_dict)

    take_test(state_name_list, state_and_capital_dict)

def get_state_and_capital():

    state_and_capital_dict = {
        "Alabama"	: "Montgomery",
        "Alaska" : "Juneau",
        "Arizona" : "Phoenix",
        "Arkansas" : "Little Rock",
        "California" : "Sacramento",
        "Colorado" : "Denver",
        "Connecticut" :	"Hartford",
        "Delaware" : "Dover",
        "Florida" : "Tallahassee",
        "Georgia" : "Atlanta",
        "Hawaii" : "Honolulu",
        "Idaho" : "Boise",
        "Illinois" : "Springfield",
        "Indiana" : "Indianapolis",
        "Iowa" : "Des Moines",
        "Kansas" :	"Topeka",
        "Kentucky" : "Frankfort",
        "Louisiana" : "Baton Rouge",
        "Maine" : "Augusta",
        "Maryland" : "Annapolis",
        "Massachusetts" : "Boston",
        "Michigan" : "Lansing",
        "Minnesota" : "Saint Paul",
        "Mississippi" :	"Jackson",
        "Missouri" : "Jefferson City",
        "Montana" :	"Helena",
        "Nebraska" : "Lincoln",
        "Nevada" : "Carson City",
        "New Hampshire" : "Concord",
        "New Jersey" : "Trenton",
        "New Mexico" : "Santa Fe",
        "New York" : "Albany",
        "North Carolina" : "Raleigh",
        "North Dakota" : "Bismarck",
        "Ohio" : "Columbus",
        "Oklahoma" : "Oklahoma City",
        "Oregon" : "Salem",
        "Pennsylvania" : "Harrisburg",
        "Rhode Island" : "Providence",
        "South Carolina" :	"Columbia",
        "South Dakota" : "Pierre",
        "Tennessee" : "Nashville",
        "Texas" : "Austin",
        "Utah" : "Salt Lake City",
        "Vermont" :	"Montpelier",
        "Virginia" : "Richmond",
        "Washington" : "Olympia",
        "West Virginia" : "Charleston",
        "Wisconsin" : "Madison",
        "Wyoming" :	"Cheyenne",
    }

    return state_and_capital_dict

def get_random_value_dict(state_and_capital_dict):

    print()
    print("This program is going to quiz you its going to give u the name of a state"
          "\nand its your job to figure out the capital: ")

    state_name_list = []

    for each_name in state_and_capital_dict.keys():
        state_name_list.append(each_name)

    return state_name_list

def take_test(state_name_list, state_and_capital_dict):

    wrong_count = 0
    right_count = 0

    another = "Y"

    while another.upper() == "Y":

        state_random_choice = random.choice(state_name_list)

        print(f"\nWhat is the capital of {state_random_choice}?")

        user_input = input("Enter your answer: ")

        if user_input in state_and_capital_dict.values():
            print("That is the correct answer")
            right_count += 1
        else:
            print("That is incorrect")
            wrong_count += 1

        print("Enter R to get your results:")
        another = input("Would you like to do another question? (Y to keep going anything else to stop) ")

        if another.upper() == "R":

            print(f"The amount that you got wrong is {wrong_count}")
            print(f"The amount that you got right is {right_count}")

main()

#_______________________________________________________________________________________________________
# SUMMARY:
    # So this code is going to be quizing the user its going to be asking the user for the state name and then when
        # it comes to the capital the user has to enter a response and thus doing so the computer is checking to see
        # if the user input is going to be correct or not and then it displays the result so the thing that I had
        # started with was that I found the key value and the its pair value and thus was doing the whole putting the
        # dict together first I was thinking that maybe I should write it to a text file or something but then the
        # idea came to me where I was like if I do all that then I have to read from file and then store to list and
        # then find a way to store it all in dict once I had gotten the dict together the next thing that I had done 
        # was that I used the keys and stored all the keys into a list this was something that I thought would help 
        # me later on in the code because I knew that I was working with random and I needed to access the list so thus 
        # doing so what had happened was that I was able to access the list and possible run the random function on the
        # list now the thing that I wanted to focus on here was that this was something that I had already done where 
        # I was accessing a random value from a list now the thing that came to my mind was that how did I do that ?
        # becasue that was something that I had forgotten so the last thing that I had done was that I used this 
        # function called take the test and what this would have done was that it was supposed to chose a random key 
        # from the list or element and then cross reference with the user input and then keep a track of the grade of 
        # how many questions that they gotten right and how many questions that they had gotten wrong the thing that 
        # I wanted to highlight here was that

"""
        state_random_choice = random.choice(state_name_list)
"""
        # so in this line of code this was something that was a crucial step to solving this code very simple we get 
        # the random module which then we access the choice function and then put in our list at first I was like wait 
        # is randint() going to be best for this and this was an idea that I had but the problem with this was that 
        # thus doing so I had to speicfy the value and then it was not making sense so then I went online and saw the 
        # choice function once I was able to pick a choice from the list then the code become more simple all I had to 
        # do was use the user input with the choice that was random and thus compare them and keep an accumulator on it 
        # overall the most important thing to understand here is that the use of key() and the use of values() was 
        # able to help us further understand this more and thus doing so we were able to write this code more effective

# %%
# So this code opens a specifed text file reads its content then uses a dict to write an encrypted version of the
    # file contents to a second file each character for the secoond file should contain the code for the
    # corresponding character in the first file
def main():
    codes = encrypt_key()

    read_from_dummy_data()

    list_containing_text = read_from_dummy_data()

    each_letter_list = get_letter_list(list_containing_text)

    encrypted_file = translate_document(each_letter_list, codes)

    write_encrytped_message_to_file_function(encrypted_file)

def encrypt_key():

    codes = {"A": "%", "a": "1", "B": "@", "b": "2", "C": "*", "c": "3", "D": ">" , "d": "4", "E": "<",
             "e": "5", "F": "?", "f": "6", "G": ":", "g": "7", "H": "}", "h": "8", "I": "[", "i": "9",
             "J": "_", "j": "10","K": "||", "k": "11", "L": "+", "l": "12", "M": ",,", "m": "13", "N": "+",
             "n": "14", "O": "==", "o": "15", "P": "^^", "p": "16", "Q": "%%", "q": "17", "R": "^&",
             "r": "18", "S": "{=", "s": "19", "T": "}|", "t": "20", "U": "?>", "u": "21", "V": "$A^",
             "v": "22", "W": ",||", "w": "25", "X": "_+_", "x": "26", "Y": "_*)", "y": "27", "Z": "_{||",
             "z": "27", " ": "|||" }

    return codes

def read_from_dummy_data():

        obj_file = open("dummy_data.txt", "r")

        obj_file_readlines = obj_file.readlines()

        list_containing_text = []

        index = 0

        while index < len(obj_file_readlines):
            element = obj_file_readlines[index].rstrip("\n")
            list_containing_text.append(element)
            index += 1

        return list_containing_text

def get_letter_list(list_containing_text):

    list_of_words = []
    list_of_each_letter = []

    for each_line in list_containing_text:
        for each_word in each_line.split():
            list_of_words.append(each_word)

    for each_word in list_of_words:
        for each_letter in each_word:
            list_of_each_letter.append(each_letter)

    return list_of_each_letter

def translate_document(each_letter_list, codes):

    translated_list = []

    for each_char in each_letter_list:
        if each_char in codes.keys():
            encrypt_code = codes[each_char]
            translated_list.append(encrypt_code)

    return translated_list

def write_encrytped_message_to_file_function(encrypted_file):

    dummy_write_encrypt_obj = open("encrypted_message.txt", "w")

    for each_line in encrypted_file:
        dummy_write_encrypt_obj.write(each_line)

    dummy_write_encrypt_obj.close()

    print(f"data has been copied to encrypted_message.txt")

main()
#_________________________________________________________________________________________________
# SUMMARY:
    # So lets start off with the very first thing here and that is the encrypt key function the thing that you want to
        # take away from here is that we are making our own rubric here we have each letter and then we have each symbol
        # with it and this is going to act as our key and value to decipher the whole code down I dont want to go into
        # to much detials but the thing that I wanted to mention here was that when it comes to this code this shows how
        # we can use dicts that store key and their values to create our own morse code in a way the next thing that we
        # are going to be talking about is the read from file this is something that we already covered here and the
        # thing that we need to know here is that its simple we are just reading from a file opening it parsing it and
        # then saving the outcome to a list the next thing that we are going to be talking about is the get_letter
        # function now this one is really simple to understand its us going through the list and then using the split
        # function and breaking it down by word for each element and then breaking it down by letter and then storing
        # it to a list so we can use that list for later on something that I wanted to mention here was that we are 
        # using two approaches first we are getting each line and then each line we are getting each word thanks to 
        # the split function we then make a separate for loop which is going to access each word and then each letter 
        # and thus write each letter to the list the next part of the code is really easy to understand what we are 
        # doing is that take a look down below and you will see...        

"""
    for each_char in each_letter_list:
        if each_char in codes.keys():
            encrypt_code = codes[each_char]
            translated_list.append(encrypt_code)

"""
        # here the thing that you need to know of what is going on is that we are getting each char in the list and 
        # then we are using a conditon statement that is checking each index value with the key value and then we set 
        # a new variable called encrypt_code which is going to be the dict[string_value] and then adding that to the 
        # list and thus doing so what happens is that we get the typed out code in encrypted list the last part is 
        # really simple to understand what we do is that we type out the last part as it is to a file and thus we get 
        # the translated version and the letter version overall the one drawback to this code is the spacing the code 
        # is working just fine but when it comes to the split since we ran it on each words it does what its supposed 
        # to where it breaks the list by words but the thing that you need to know here is that since there are no 
        # space in the list it means that there wont be space in the outcome we can change it by running split on each 
        # word but then its hard to read the sentence so that is the only draw back to this code other then that when 
        # it comes to concept I think that I have a firm understanding of how to use list dicts and methods and stuff 
        # so yea good stuff.

# %%
# This program is writes a specifed text file then displays a list of all the unique words found in the file
def main():

    write_to_file()

    set_list_random_txt = read_from_file()

    display_unique_words(set_list_random_txt)

def write_to_file():

    create_file = open("random.txt", "w")

    another = "Y"

    while another.upper() == "Y":

        user_input = input("Enter something and then I will add it to the random.txt file: ")

        create_file.write(user_input + "\n")

        another = input("Enter y to add another name otherwise enter anything else to stop the program: ")

    create_file.close()

def read_from_file():

    list_random_txt = []

    read_file = open("random.txt", "r")

    read_file_obj = read_file.readlines()

    index = 0

    while index < len(read_file_obj):
        line = read_file_obj[index].rstrip("\n")
        list_random_txt.append(line)
        index += 1

    set_list_random_txt = set(list_random_txt)

    return set_list_random_txt

def display_unique_words(set_list_random_txt):

    print("Here are the names:")
    for each_element in set_list_random_txt:
        print(each_element)

    print("Process is done")

main()

#________________________________________________________________________________________________________
# SUMMARY:
    # So this program was a really simple program and something that I am not going to go into to much detail because
        # the code itself explains by itself the first function we are writting to a text file and the second one we are
        # than reading from a text file and storing the output to a list and then the last function we are going to be
        # displaying the words now the thing about this code is really simple to understand but the thing that we need
        # to know is how the use of sets are being used here so the thing that I wanted to point out here was that when
        # it comes to the text file we are storing different names into the text file and even the same name in this
        # example we have zaid repeating twice with kobe and lebron but when we print out the sets we are getting each
        # occurence name and the sets are not repeating the name that is what you need to know the use of sets is
        # causing the set to print out only one occurence and when it comes to writting in the text file we are writting
        # more than one name this code was really simple it was trying to teach how to write to file and than read from 
        # file and then use the set function to read only the unique words and not the same names over again.

# %%
from timeit import default_timer as timer

# String Notes
my_list = ["a"] * 1000000

# Bad
start = timer()
my_string = ""
for i in my_list:
    my_string += i
stop = timer()
print(f"Time took: {stop - start}")

# Good
start = timer()
my_string = "".join(my_list)
stop = timer()
print(f"Time took: {stop - start}")

#_______________________________________________________________________________________________
# SUMMARY:
    # So here in this code we are learning about the join function now the thing that we need to know here is that what 
        # we are going to be doing is increasing the list letter "a" by 1000000 so what we are doing is for each char 
        # we are adding to our string and the thing that I wanted to point out was that normally we are used to using 
        # the for loop approach where we get each element that is in the list and then we add that to our string take 
        # a look here (now the thing that I would have done is that run a for loop and then use end=" " and the get our
        # aaaaa in one line or something) what this code did instead was that it write the code to one line using an
        # empty string which I was not really thinking overall we started our timer and than stopped our timer and then 
        # we got the run time and notice the "bad" way of doing it is something that we are always doing where we get 
        # each index using a for loop now the smarter apprach is to use the joing function here we are saying joing the
        # list with out any spaces and the best way to understand this logic is that we bypassing the highway that is 
        # loop around a city and instead we are getting straight to the destination using local routes the thing that I 
        # found out interesting in this code was that when it comes to concepts there is a smarter way of doing things 
        # and that is important to understand it takes less time to use the join super important.

# %%
# This program reads the contents of a text file the program should create a dict in which the keys are the individual
    # words found in the file and the values are the number of times each word appear the program should either display
    # the freq of each word or create a second file containing a list of each word and its freq.
def main():

    read_file_obj_parse_list = read_from_file()

    create_dict(read_file_obj_parse_list)

def read_from_file():

    read_file = open("file_data.txt", "r")

    read_file_obj = read_file.readlines()

    index = 0

    # Create the parse list
    read_file_obj_parse_list = []

    # Parse the data
    while index < len(read_file_obj):
        element = read_file_obj[index].rstrip("\n")
        read_file_obj_parse_list.append(element)
        index += 1

    return read_file_obj_parse_list

def create_dict(read_file_obj_parse_list):

    read_from_file_dict = {}

    list_with_all_words = []

    for each_element in read_file_obj_parse_list:
        for each_word in each_element.split():
            list_with_all_words.append(each_word)

    # Convert to Set
    empty_set = set(list_with_all_words)

    for each_element in empty_set:
        read_from_file_dict[each_element] = list_with_all_words.count(each_element)

    print(read_from_file_dict)

main()

#________________________________________________________________________________________________________
# SUMMARY:
    # So here the thing that you need to know is that the first function we are creating is called the read_from_file
        # function here what we are doing is that we are storing the contents in the very first function its really
        # simple what is going on we are reading from file_data_txt and we are parsing the data and storing to a new
        # list return list to a variable and thus use that variable for another function the next function is called
        # the create_dict we are using the list that is parsed now the thing that I wanted to mention here was that
        # when it comes to the parse list we have the list which is storing each element like this look below...
"""
    # ["hello there my name is zaid", " nice to meet you"]
"""
        # notice how this list has two elements this is prior to using split the next thing that we did was that we
        # had gotten each element and then split so essentially we are running split on hello there my name is zaid line
        # and thus doing so we were able to break the list down to more words so what I did was that I now created a
        # empty list that is storing all the words so this line for each_word in each_element.split(): what this is
        # saying is that each_word stands for each_element.split() so now each_word becomes the element split so that
        # what the point of reference is the next thing that we need to focus on here is empty_set variable and the
        # thing to know here is that this is going to reference the next that we did was that we converted the code to
        # a set because we dont want any words to repeat for the key in dicts you cant do that therefore we have to
        # use sets once we used the set we then got our keys the thing that I wanted to fouus on here was that when it
        # comes to this code the mistake that I made was that I was getting the key value but I was not putting the
        # value value take a look at the next line...
"""
    for each_element in empty_set:
        read_from_file_dict[each_element] = list_with_all_words.count(each_element)
"""
        # I knew that I was going to use the first half of the code where I use a loop and get each element of all the
        # words and then use the dict to store the variable that is holding the string into the dict but I was not
        # putting the value next to it and now the idea came to my mind where I need to see the occurence of the words
        # now keep in mind in the set the words only occur once and when it comes to all its occurence we used the
        # list that has every word occurence and then it was simple I used the count on the list to keep track of each
        # element in the set value and then mapped it out in a dict overall this code was really simple to write and 
        # really not that complicated.

# %%
x = ("apple", "banana", "cherry", "apple")
y = list(x)
y[1] = "kiwi"
x = tuple(y)

print(x)


#__________________________________________________________
# SUMMARY:
    # So here this code is really simple but the thing that had came to mind was that what was the difference between
        # tuples and sets in my mind I was thinking that tuples are the ones that dont change when in reality it was
        # sets and the other mistake that I did was that I was thinking that sets have () when that is tuple it shows
        # that I only know it brief but when it comes to working with sets its with the whole symmeteric difference and
        # everything but when it comes to working with tuples the thing that you need to know is that its going to be
        # like the thing that you see above another key thing that I had gotten wrong was that I was thinking that when
        # it comes to sets they dont repeat but here I was thinking that tuples dont repeat but they do so here the
        # thing that you need to know is that we created a tuple and then changed the tuple to a list and at the 1 index 
        # we changed the banana to kiwi and then changed it back to tuple this was something cool because this gave me 
        # the idea say you needed to add something to a tuple you can change it to a list and then add something or 
        # make an element change and then change it back to a tuple I thought that was a genius move and something that 
        # changed the way I look at things

# %%
# This program reads the contents from two text files and compares them in the following ways
    # It should display words that appear in both files
    # It should display a list of words that appear in the first file but not the second file
    # It should display a list of words that appear in the second file but not the first
    # It should display a list of the words that appear in either the first or second file but not both
def main():

    first_file_list_with_words, first_file_text_set = read_from_the_first_file()

    second_file_list_with_words, second_file_text_set = read_from_second_file()

    display_everything(first_file_list_with_words, first_file_text_set, second_file_list_with_words,
                       second_file_text_set)

def read_from_the_first_file():

    read_first_file = open("first_random_file.txt", "r")

    read_first_file_obj = read_first_file.readlines()

    first_file_text_list = []
    first_file_list_with_words = []

    # Parse the List
    index = 0

    while index < len(read_first_file_obj):
        element_rstrip = read_first_file_obj[index].rstrip()
        first_file_text_list.append(element_rstrip)
        index += 1

    for each_element in first_file_text_list:
        for each_word in each_element.split():
            first_file_list_with_words.append(each_word)

    first_file_text_set = set(first_file_list_with_words)

    return first_file_list_with_words, first_file_text_set

def read_from_second_file():

    read_second_file = open("second_random_file.txt", "r")

    read_second_file_obj = read_second_file.readlines()

    second_file_text_list = []
    second_file_list_with_words = []

    index = 0

    while index < len(read_second_file_obj):
        element_rstrip = read_second_file_obj[index].rstrip("\n")
        second_file_text_list.append(element_rstrip)
        index += 1

    for each_element in second_file_text_list:
        for each_word in each_element.split():
            second_file_list_with_words.append(each_word)

    second_file_text_set = set(second_file_list_with_words)

    return second_file_list_with_words, second_file_text_set


def display_everything(first_file_list_with_words, first_file_text_set, second_file_list_with_words,
                       second_file_text_set):
    print()
    # Display unique words in first random file
    print("Unique words in first_random_file.txt is:")
    for each_word in first_file_text_set:
        print(each_word)
    print()

    # Display unique words in first random file
    print("Unique words in second_random_file.txt is:")
    for each_word in second_file_text_set:
        print(each_word)
    print()

    # Get the word difference of first file - second file
    print("The words that appear in the first file and not the second is:")
    first_file_difference = first_file_text_set - second_file_text_set
    for each_word in first_file_difference:
        print(each_word)
    print()

    # Get the word difference of second_file - first_file
    print("The words that appear in the second file and not the first is:")
    second_file_difference = second_file_text_set - first_file_text_set
    for each_word in second_file_difference:
        print(each_word)
    print()

    # Get the symmeteric difference between the first_file and the second_file
    print("The uncommon words between the first file and second file is:")
    symmeteric_difference = first_file_text_set.symmetric_difference(second_file_text_set)
    for each_word in symmeteric_difference:
        print(each_word)
    print()

main()

#___________________________________________________________________________________________________
# SUMMARY:
    # So what we started with was that the first two functions we are just reading from the file we open the file that
        # we want then run splitlines and then parse the list store content of parsed list to a new list and then we
        # run a for loop on the new parsed list and for each element we run split so that we can get each separate word
        # and we store that word to a new list that contains each word and thus run the set method and convert that
        # list that is containing all the words from the file and stores the words that dont repeat we then return the
        # list and then the set for each file and then call those 4 to the display function where we can display the
        # results so this code was really simple because its this concept that we learned take a look below...
"""
    set_one = {"a", "b", "c"}
    set_two = {"b", "c", "d", "e"}
    
    x = set_one - set_two
    print(x)
    
    y = set_two - set_one
    print(y)
    
    z = set_one.symmetric_difference(set_two)
    print(z)
    
    a = set_one.union(set_two)
    print(a)
"""
        # the thing that I leanred was that when it comes to set being subtracted from one another we are finding the
        # difference of the sets meaning that the elements that are repeating we are subtract them from the other set
        # whatever is remaining in that set after each element that is the same from the set is removed is the new
        # set value so b and c are in set two and a is not so a is the set value this was something that I covered in
        # my notes but its cool to see how this can look practically the other thing that I wanted to mention was that
        # the outcome is still stored in set so that is important to understand which its self explantory that if
        # int - int = int then set - set = set so that means we can use a for loop to get each element the other thing
        # that I wanted to mention was that when it comes to working with sets this shows us how they can be practical
        # meaning that since we have random data that is stored to two random text file that means that this shows us 
        # we can get each set value values that dont occur over and over again and use the methods in a real world 
        # scenerio

# %%
# Normal Way of doing it
fruits = ["apple", "banna", "cherry", "kiwi", "mango"]
new_list = []

for x in fruits:
    if "a" in x:
        new_list.append(x)

print(new_list)
print()

# List Comprehension
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
new_list = [x for x in fruits if "a" in x]
print(new_list)


#________________________________________________________________________________________
# SUMMARY:
    # So this is something that I wanted to cover in the first line we have a list that has all these elements of
        # fruits and then a new empty list we then are getting each element in the list and we are saying that if "a"
        # is in the element than append that element to the empty list and then print the new list but there is a new
        # and eaiser way to do this for example we have the same list and notice how in the list we have [ ] look below
"""
    newlist = [expression for item in iterable if condition == True]
"""
        # this is saying that for each element in the list if the character a is in the element then add that element
        # so the only thing to know here is that the first x means that the the x that pass the condition of the element
        # then add them to our list so the best way to read it is starting with the for loop and then using the if
        # condition and then reading the last x as a way of saying that add x to the list that was something that I was 
        # like oh I see that makes sense and it shortens the code down more.

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.update({"year": 2020})

print(thisdict)

#_________________________________________________________________________________
# SUMMARY:
    # So here the thing that we need to know is taht we can use the update method and that is really simple to 
        # understand because all we are doing is calling update and we call a key and then its value and then put it 
        # in a {} to show that this is going to be added to our dict and we then are printing out the dict that is 
        # something that you need to know here its a shorter way instead of writting it the usual format
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2020}

# %%
# This program reads this file and creates a dict in which the keys are the names of the teams and each key assoicated
    # value is the name of the team that won that year, the program should prompt the user for a year in the range of
    # 1903 through 2009 it should then display the name of the team that won the World Series that year and the number
    # of times that team has won the World Series.

def main():
    # So here I had gotten two things the world series parsed list which was the list of the team names without the \n
        # character and the second thing was the set_world_series which was the set of the list and it removes the
        # repeating elements and puts them into a set.
    world_series_parsed_list, set_world_series = read_from_file_function()

    # So here we are putting the set and the list into the dict world series where we are going to be getting the name
        # of the team and how many times the team has won we need to use both the set and the list to accomplish this.
    dict_world_series = set_dict_world_series_function(world_series_parsed_list, set_world_series)

    # This is going to be storing the years into a list we are going to be using this for later on.
    years = get_year_function()

    # This is going to be storing a dict that is going to have look like {"1997" : Yankees}
    dict_to_zip_years_team_won = year_to_team_function(years, world_series_parsed_list)

    display_data(dict_to_zip_years_team_won, dict_world_series)

    print(f"dict_to_zip: {dict_to_zip_years_team_won}")
    print(f"dict_world_series: {dict_world_series}")

def read_from_file_function():

    world_series_file = open("WorldSeriesWinners.txt", "r")

    world_series_obj = world_series_file.readlines()

    world_series_parsed_list = []

    index = 0

    while index < len(world_series_obj):
        element = world_series_obj[index].rstrip("\n")
        world_series_parsed_list.append(element)
        index += 1

    # Get the total amount of teams that played
    set_world_series = set(world_series_parsed_list)

    return world_series_parsed_list, set_world_series

def get_year_function():

    year_world_series = []

    for year in range(1903, 2007):
        year_world_series.append(year)

    return year_world_series

def set_dict_world_series_function(world_series_parsed_list, set_world_series_names):

    dict_world_series = {}

    for each_name in set_world_series_names:
        dict_world_series[each_name] = world_series_parsed_list.count(each_name)

    print()
    print("The team and the amount that the team won dict is below:")
    print(dict_world_series)

    return dict_world_series

def year_to_team_function(years, world_series_parsed_list):

    year_to_team_dict = {}

    # Zip function allows us to use two list together and have key and value pairs
    zip_years_team_won = zip(years, world_series_parsed_list)

    # Convert to dict file from zip
    dict_to_zip_years_team_won = dict(zip_years_team_won)

    # Display the results
    print()
    print("The team that won each year from 1903 to 2009: ")
    print(dict_to_zip_years_team_won)

    return dict_to_zip_years_team_won

def display_data(dict_to_zip_years_team_won, dict_world_series):

    print()
    user_input_year = int(input("Enter a year from 1903 to 2009: "))

    if user_input_year >= 1903 and user_input_year <= 2009:

        print(f"The team that won in {str(user_input_year)} was {dict_to_zip_years_team_won[user_input_year]}")

        if dict_to_zip_years_team_won[user_input_year] in dict_world_series.keys():

            team = dict_to_zip_years_team_won[user_input_year]

            print(f"The amount of times that {dict_to_zip_years_team_won[user_input_year]} won is "
                  f"{dict_world_series[team]} times")

    while user_input_year <= 1903 or user_input_year >= 2009:

        user_input_year = int(input("Enter a proper year from 1903 to 2009: "))

        if user_input_year >= 1903 and user_input_year <= 2009:

            print(f"The team that won in {str(user_input_year)} was {dict_to_zip_years_team_won[user_input_year]}")

            if dict_to_zip_years_team_won[user_input_year] in dict_world_series.keys():
                team = dict_to_zip_years_team_won[user_input_year]

                print(f"The amount of times that {dict_to_zip_years_team_won[user_input_year]} won is "
                      f"{dict_world_series[team]} times")

main()

#_________________________________________________________________________________________________________
# SUMMARY:
    # So in the function read_from_file_function() it was really simple what was going on we get the WorldSeriesWinner
        # and open the file in read mode we then put it in a list parse the file and store to a separate parsed list
        # and then make a set and return the list and the set the next function was a more simple function then the one
        # that we have where get the year and store it to an empty list the year starts from 1903 to 2007 up to 2006
        # and then store that we need this for later on in the code now here is where we are trying to get the name of
        # team and how many times the team has won we started off with an empty dict and now we need to add keys and
        # their values for the keys we are going to be using the set values because keys dont repeat and when it comes
        # to values we are going to be using the list what I did was that I got each element in the set and then I used
        # that variable value to get the name and then get the count so for the key we just use the dict and we use the
        # key to get the name and for the value we used the list that has all the amount of times the name occurs and
        # keep a count this is possible because we understand that when it comes to dicts we need to know how to input
        # keys into dict and when it comes to values we know how to set values and the thing that I wanted to highlight
        # was that notice that we can just use the list and then the count the number of times the words repeat in each
        # set for example the best way to describe this is that we are using the sets to and then using the list to
        # count the names and it shows how we can use the sets as the values and then the list as the values.
        # The next thing that we are working on the year_to_team_function here we are taking the years and then we are
        # taking the world series parsed list the world series parsed list and the thing to know here is that they are
        # both list now what we are doing is that so what we are doing is that this function is going to be returning
        # the the year and what team that won that year so the thing that I wanted to mention here was that the key is
        # going to be each element in the list one for the key and one for the value and the only way that we can do is
        # using the zip function I was trying to figure out a way to do both so what I used the function below...
        # zip(years, world_series_parsed_list) here one side is the years and the other side is the parsed list and the
        # next line of code is dict_to_zip_years_team_won = dict(zip_years_team_won) it converts the zip function to a
        # dict and now this is going to print out the year and the team code on bottom helped out.
"""
    list_a = ["a", "b", "c"]
    list_b = ["x", "y", "z", "a"]
    
    zip_iter = zip(list_a, list_b)
    dict_zip = dict(zip_iter)
    
    print(dict_zip)
"""
    # The last function is really simple function in which we are getting the team that won during the year where the
        # user enters and then it displays how many times the team won and for that we are going to be needing the
        # dict_to_zip years team won dict because this is a dict that is storing the year and the team that won that
        # year and the other is the dict world series which is the name of the team and how many times the team has won
        # its the one that keep the count of the wins so we start off by getting the user input and we need to write a
        # conditional statement that is saying something regarding that if the user enters something within in the year
        # then print the team that won that year the reason being that when it comes to the dict_to_zip that is going
        # to be a dict that is storing the year and team that won so when we are calling the dict we are calling the
        # year as the key so that we can get its value the second thing that we had to do was to get the times the team
        # had won and notice this is something that we already had saved in our dict here we are going to be using the
        # year the team won and then the dict that tells how many times the team won so here this is saying if the team
        # is in the dict_world series key then we store the value of team to a variable and then call that variable in
        # the dict_world_series[team] this is referring to the amount of times that team has won
"""
    dict_to_zip: {1903: 'Boston Americans', 1904: 'New York Giants', 1905: 'Chicago White Sox',}
    dict_world_series: {'Milwaukee Braves': 1, 'Baltimore Orioles': 3}
"""
        # so the other thing that I wrote in my while loop was that if the user has put something without the range that
        # we are looking for we need to do something we cant just let it go uncheck here so this loop is going to
        # repeat we are going to get the input from the user again and then we say if the user input is within that
        # range then we do the same thing that we are told to do on the top and notice how we are using the or and
        # operator the thing that I wnated to mention here was that I think there is a better way to write this code
        # but since the scope of this so for example the first time someone writes say 2010 this is not in range so 
        # it goes to the while clause then it ask for the proper input then they enter 2010 and it ask them again and 
        # then here we have to state what need to happen say they enter something proper and that all goes back to the 
        # scope overall this code I could have chose better variable names to make this more eaiser to understand

# %%
class Payment:

    def __init__(self, price):
        self.__final_price = price + (price * 0.05)

    def get_final_price(self):
        return self.__final_price

    def set_final_price(self, discount):
        self.__final_price = self.__final_price - (self.__final_price * (discount/100))

# Input the preset value that is going to be calculated
book = Payment(10)

# Try to change it wont be able to
#book.__final_price = 0

# Here we created a function that is going to be manipulating our respoonse but not changing it
book.set_final_price(10)

# Display the results
print(book.get_final_price())

#___________________________________________________________________________________________
# SUMMARY:
    # Something that we are going to be talking about is public and private variable the things that we need to know
        # here is that we have the __init__ function that is taking the price and year we then passed in self to the
        # init function and then we said self.final_price = price * price * 0.5 and then we did self.year = year and
        # then we created an object variable that is called book that is holding in the class called Payment and then
        # we passed in 10 and 1997 and the thing that I learned here was that the 10 is going into price and the 1997
        # is going into year so when we called the book.final_price and we did self.year the thing that we need to know
        # is that we are doing is going onto the left side of the self bracket and thus doing so we pass in the variable
        # and the thing that we need to know is that when we do the book.final_price and book.year we are passing in the
        # something that I wanted you to pay attention was here in this step take a look down below...
"""
book.final_price = 0
"""
        # something that we need to know here is that here we are over ridding the final_price with zero and the thing
        # that we need to know is that its going to be 0 the cool thing that we need to know here is that when we put
        # it this way we are over ridding the value that is on the left the next thing that we are going to be talking
        # about is public and private variable and public variable here are some notes that I learned thus far that you
        # need to know
        # Procedural programming is a method of writting software it is a programming practice centered on the procedure
            # or actions that take place in a program Object oriented programming is centered on objects Objects are
            # created from abstract data types that encapsulates data and functions together. Procedural simply as a
            # function that performs a specific task such as gathering input from the user performing calculations
            # reading or writting files.
"""
    class Payment:
    
        def __init__(self, price, year):
            self._final_price = price * price * 0.5
            self.year = year
    
    book = Payment(10, 1997)
    book._final_price = 0
    print(book._final_price)
    print(book.year)
"""
        # So here the thing that I wanted to mention was that we are using private variable now the thing that we need
        # to know when it comes to working with private variables is that you are using one underscore and thus that
        # means that we are using private variables now the thing that I wanted to mention here was that doing this is
        # more so of kind of telling the people that hey this is a private variable it really doesnt do anything meaning
        # that when you override the value with zero then you are getting the same result had you not used the _ now
        # when it comes to where you cant change it at all then you have to use __ take a look below
"""
    class Payment:
    
        def __init__(self, price):
            self.__final_price = price + price * 0.05
    
        def get_final_price(self):
            return self.__final_price
    
    # Input the preset value that is going to be calculated
    book = Payment(10)
    
    # Try to change it wont be able to 
    book.__final_price = 0
    
    # Display the results
    print(book.get_final_price())
"""
        # So here the thing that you need to know is what is going on here notice this we have two __final_price here
        # and the thing that we need to know what is going on here is that when we are using the double underscore on
        # the first side we cant change the variable that is something important to consider so take a look at what is
        # going on here we have the __init__ method that is taking in the argument price and then we are passing in the
        # self once we do that notice in the __final_price variable we have set __ two underscore and when it comes to
        # this we cant change the calue of the inner variable so the only way we can access the value is by using a get
        # method and that is going to return the final price so notice the next function that we created its basically
        # returning the final price with the self and then we created an obj variable to the class of Payments and thus
        # we were able to call the class then the method and we put 10 because that that is going into our spine of the
        # code and thus we are using the standard parameter and arguments and the last thing that we did was we tried
        # to overide the __final_price and thus we were not able to so that is why we used the __ and then we just
        # printed what was out on the variable that is something important that you need to understand what is going on
        # here.
        # Recap notes: Object oriented programming is centered on creating objects an object is a software entity that
        # contains both data and procedure the data contained in an object is known as the object data attributes an
        # object data attributes are simply variables that reference data the procedure that objects perform are known
        # as methods encapsulation refers to the combining of data and code into a single object data hiding refers to
        # an object ability to hide its data attributes from code that is outside the object. SO here the thing that you
        # might be wondering is how is this encapsulation and the best way to think of encap is that think of a tablet
        # or capsule it hides the ingridents from the user protected fillament and then the drug works when it enters
        # the body the same thing is going on here same thing is going on here when we pass in 10 to Payments its then
        # going to the self branch and we cant overide the value therefore we are encap it so that no one can change
        # the value.

"""
    class Payment:
    
        def __init__(self, price):
            self.__final_price = price + (price * 0.05)
    
        def get_final_price(self):
            return self.__final_price
    
        def set_final_price(self, discount):
            self.__final_price = self.__final_price - (self.__final_price * (discount/100))
    
    # Input the preset value that is going to be calculated
    book = Payment(10)
    
    # Try to change it wont be able to
    #book.__final_price = 0
    
    # Here we created a function that is going to be manipulating our respoonse but not changing it
    book.set_final_price(10)
    
    # Display the results
    print(book.get_final_price())

"""

        # So the thing that we need to know here is that we created another function that is called the set_final_price
        # and in it we have the self and then the discount and the thing that we need to know here is that when we are
        # putting the self.__final_price and then subtracting it from the discount price the two new things that I had
        # learned in this code was that when it comes to the Payment(10) and then when it comes to the the discount
        # variable the 10 goes into the __final_price and in the next line of code look below...
"""
        def set_final_price(self, discount):
            self.__final_price = self.__final_price - (self.__final_price * (discount/100))
"""
        # we are using the values within the __final_price and then discount we are taking in a 10 because of this line
        # look below...
"""
    book.set_final_price(10)
"""
        # this will go to the discount and not the so the thing that I learned was that there are two ways to over ride
        # a variable one is through the class or brain and the other is through the spine.

# %%
class Person:

  def __init__(mysillyobject, name, age):
    mysillyobject.name = name
    mysillyobject.age = age

  def myfunc(abc):
    print("Hello my name is " + abc.name)

p1 = Person("John", 36)
p1.myfunc()

#______________________________________________________________________________________________________
# SUMMARY:
    # So here we are going to be talking about self and something that I wanted to highlight here was that the question
        # that I had to myself was what exactly is self? so take a look here before we begin to write this code the
        # thing that we need to know is that self is used more so as a naming convention you can use anything but the
        # definition to this is that the self parameter is is a reference to the current instance of the class and is
        # used to access variables that belgons to the class notice how we created the self we stated that mysillyobject
        # and had name and age set there and the next function that we created instead of writting self we wrote abc
        # and then we try to get access from the spine and then when we print this out or fill in the parameter value
        # with arguments we call the function and get this down below...
"""
    Hello my name is John
"""
        # now the thing to know here is we created an object of the class and filled in the parameters and thus doing
        # so we called the function that we want to access and here its going to be getting the name or the variable
        # that is within the spine of the code but this code is important because it shows us that this is all naming
        # convention we can use anything we want it doesnt have to be something that similar but its better if it is
        # because it make the code more easier to read and reason why is so we can always have access to the spine
        # Notes from the book: the self parameter is required in every method of a class a method operates on a specific
        # object data attributes when a method exectues it must have a way of knowing which object data attributes
        # it is supposed to operate on that is where the self parameter comes in when a method is called python makes
        # the self parameter reference the specific object that the method is supposed to operate on

# %%
import random

# The Coin class simulates a coin that can
# be flipped

class Coin:

    # The __init__ method initializes the side up data
    # attribute with 'Heads'

    def __init__(self):
        self.sideup = 'Heads'

    # The toss method generates a radnom number
    # in range of 0 through 1. If the number is
    # 0 then sideup is set to 'Heads'. Otherwise
    # sideup is set to 'Tails'

    def toss(self):
        if random.randint(0, 1) == 0:
            self.sideup = 'Heads'
        else:
            self.sideup = 'Tails'

    # The get_sideup method returns the value
    # referenced by sideup.

    def get_sideup(self):
        return self.sideup

# The main function
def main():
    # Create an object from the Coin Class
    my_coin = Coin()

    # Display the side of the coin that is facing up
    print("This side is up:", my_coin.get_sideup())

    # Toss the coin
    print("I am tossing the coin...")
    my_coin.toss()

    # Display the side of the coin that is facing up
    print("This side is up:", my_coin.get_sideup())

# Call the main function
main()

#___________________________________________________________________________________________________________
# SUMMARY:
    # So the first method is named the __init__ which automatically executed when an instance of a class is created in
        # memmory this is known as the initilizer method because it initilizes the object data attributes after the
        # object is created in memory the init method executes and the self parameter is automatically assinged the
        # object that was created so for example the statement 'Heads' is assigned to the sideup data attribute
        # belonging to the object that was just created as a result the init method each object we create from the
        # Coin class initially have a sideup attribute that is set to Heads (is usually the first method in class def)
    # The next method that we are going to be talking about is the toss method it has required a self parameter varible
        # when the toss method is called self will automatically reference the object on which the method is to operate
"""
        self.sideup = 'Heads'
"""
        # so here the thing that you need to know is that the statement assigns the string 'Heads' to the sideup data
        # attribute belonging to the object that was just created as a result to this each object that we create from
        # the Coin class will initially have a sideup attribute that is set to 'Heads'
"""
    def toss(self):
        if random.randint(0, 1) == 0:
            self.sideup = 'Head'
        else:
            self.sideup = 'Tails'
"""
        # So this method also has required self parameter variable when the toss method is called self will
        # automatically reference the object on which the method is set to operate the toss method simulates tossing the
        # coin.
    # So here is what I think is happening in this code the first thing that I want to begin by is that this code is
        # that we are going to begin with the self.sideup set to heads and at first I was wondering why are we doing
        # this here and it became really simple not the get_sideup what we are doing is returning the sideup value and
        # that being the next thing that we are doing is we created the toss method and what it does is that it saying
        # that if a random.randint(0,1) == 0 now the mistake that I made here was that i was using the "" instead of the
        # '' and the second thing that I did wrong was that I was using the == instead of = this was a rookie mistake
        # by me because I really didnt understand what was going on in this code now the question comes when it comes
        # to get_sideup(self) and then toss so the thing I wanted to highlight here was the main function take a look
        # at what is going on here...
"""
    # The main function
    def main():
        # Create an object from the Coin Class
        my_coin = Coin()
    
        # Display the side of the coin that is facing up
        print("This side is up:", my_coin.get_sideup())
    
        # Toss the coin
        print("I am tossing the coin...")
        my_coin.toss()
    
        # Display the side of the coin that is facing up
        print("This side is up:", my_coin.get_sideup())
    
    # Call the main function
    main()
"""
        # The first thing is that we are creating the main function that is underneath our class now this was new to me
        # because I was wondering to myself like I am used to creating the main block but now underneath the main class
        # then we are running the main function and something that came to me was how are we able to access each method
        # in the main class like do we import each method or something and that is not the case instead what we are
        # doing is that we set an object to the class or another name for it is an object variable and what that does
        # is that we set the my_coin = Coin() by using this when we use the obj variable we are really referencing the
        # class and then we do the class.method do in the next line we call the class object variable. method we want
        # to call and its going to be return self.sideup (def get_sideup(self)) and its going to return the value of
        # what sideup is storing and now you might be wondering what is sideup storing ? and how is it all connected and
        # the answer to that is really simple we go back to the __init__ and it is storing 'Heads' in the init so it
        # makes sense to create the init clause then make the variable and we then use that variable in other parts of
        # the program something that I wanted you to focus on here...
"""
      def __init__(mysillyobject, name, age):
        mysillyobject.name = name
        mysillyobject.age = age
"""
        # so if you notice here we are using the variable name and then setting self.name = name and then we are doing
        # self.age = age and this one we just set the variable to a string I think the reason why we do it this way is
        # that in the name and age they are what we call empty variable and we are storing the input into these variable
        # the other are strings set to variables and we are storing the string that is why we dont set it to an empty
        # variable so if we look at the main function once we get the sideup that is going to be heads and then we call
        # the toss function and that is going to be changing the value for sideup based on a random value earlier we
        # learned that how to use the random.randint(min, max) == 0 this means that if the value is equal to 0 then do
        # change it to Heads other wise change it to Tails so if the random.randint value is 1 then it is going to be
        # changing it to Tails and then when we call the get_sideup its going to be now storing tails what amazes me is 
        # how many different parts there are to this code like all the things that are working together that is the most 
        # crazy part of this code another thing that I forgot to mention was that this works similiar to encapsualtion 
        # where you hide what is going on from the user and where they can not directly change the variable and it makes
        # sense learning this like how easy it is for someone to change something in the code where we leanred how the 
        # code you have to create a function that changes the code as suppose of having someone who changes the code and
        # it makes sense as to what is going on here the on thing that I learned new that I wouldnt have known is that 
        # when it comes to this code we do the function get_sideup and it gets called after toss the thing that came to 
        # my mind is that I was like oh I forgot that this is going to be changing the value of sideup variable and when 
        # it did I was like wow its amazing how everything clicks together

# %%
import random

# The Coin class simulates a coin that can
# be flipped

class Coin:

    # The __init__ method initializes the side up data
    # attribute with 'Heads'

    def __init__(self):
        self.sideup = 'Heads'

    # The toss method generates a radnom number
    # in range of 0 through 1. If the number is
    # 0 then sideup is set to 'Heads'. Otherwise
    # sideup is set to 'Tails'

    def toss(self):
        if random.randint(0, 1) == 0:
            self.sideup = 'Heads'
        else:
            self.sideup = 'Tails'

    # The get_sideup method returns the value
    # referenced by sideup.

    def get_sideup(self):
        return self.sideup

# The main function
def main():
    # Create an object from the Coin Class
    my_coin = Coin()

    # Display the side of the coin that is facing up
    print("This side of the coin is facing up:", my_coin.get_sideup())

    # Toss the coin
    print("I am tossing the coin...")
    my_coin.toss()

    # But now I am going to cheat I am going to
    # directly change the value of the object
    # sideup attribute to 'Heads'
    my_coin.sideup = 'Heads'

    # Display the side of the coin that is facing up
    print("This side is up:", my_coin.get_sideup())

# Call the main function
main()

#____________________________________________________________________________________________________________
# SUMMARY:
    # So here this code is really similar to the other code that we wrote but the only difference is that this code is
        # calling the toss method and then its changing up the side up to Heads so then it will print out Heads the
        # reason why we are writting this code is that earlier we leanred how to hide attributes and the difference
        # between private and public data attributes and this way if we were to private it then no one can change the
        # variable so earlier I was thinking why are we running toss when we are changing the value and the answer to
        # that is really simple all we are doing is that we are changing it to Heads there really is no reason to
        # run toss so I was right
    # Something that I wanted to mention here was that when it comes to this code the thing that you need to be aware
        # here is that I learned some new things when I was doing the readin and it had talked about classes and then
        # objects of the class when you create a  class object you can then use the attributes that are in the self
        # method so that is why the instance of the class is already preloaded with Heads that was something that I had
        # learned and was like oh wow that makes sense the other thing that I had leanred was when it comes to the whole
        # objects of the class the best way to think of it is as a cookie cutter the cookie cutter is the class and the 
        # cookies that are made from the cookie cutter is the object to the class that is something that we need to 
        # know of what is going on here.

# %%
import random

# The Coin class simulates a coin that can
# be flipped

class Coin:

    # The __init__ method initializes the __sideup data
    # attribute with 'Heads'

    def __init__(self):
        self.__sideup = 'Heads'

    # The toss method generates a radnom number
    # in range of 0 through 1. If the number is
    # 0 then sideup is set to 'Heads'. Otherwise
    # sideup is set to 'Tails'

    def toss(self):
        if random.randint(0, 1) == 0:
            self.__sideup = 'Heads'
        else:
            self.__sideup = 'Tails'

    # The get_sideup method returns the value
    # referenced by sideup.

    def get_sideup(self):
        return self.__sideup

# The main function
def main():
    # Create an object from the Coin Class
    my_coin = Coin()

    # Display the side of the coin that is facing up
    print("This side of the coin is facing up:", my_coin.get_sideup())

    # Toss the coin 10 times
    print("I am going to toss the coin 10 times...")

    for count in range(10):
        my_coin.toss()

        # Display the side of the coin that is facing up
        print("This side is up:", my_coin.get_sideup())

# Call the main function
main()

#____________________________________________________________________________________________________________
# SUMMARY:
    # So before we go and begin to break this code down on what is going on here the thing that we need to know is that
        # what is going on here so earlier we did this code and take a look down below to see what it is...
"""
    # Toss the coin
    print("I am tossing the coin...")
    my_coin.toss()

    # But now I am going to cheat I am going to
    # directly change the value of the object
    # sideup attribute to 'Heads'
    my_coin.sideup = 'Heads'

    # Display the side of the coin that is facing up
    print("This side is up:", my_coin.get_sideup())
"""
        # so earlier we wrote this code and the thing to know here is that it is a very simple code to understand what
        # we had done was that we made an object to the class and then used that object to call onto the methods and
        # also call onto the data attributes in the init clause but take a look here the thing that I hadn't seen was
        # that when it comes to calling the sideup this was something in the init clause and we changed it here and
        # then we leanred what is encapsulation its basically hiding something so that other people can not modify it
        # and then I thought last code we were also doing encaps but not really we were changing the value so in this
        # code in the green we are changing the value now to combat someone changing poritons of your code to something
        # else what you can do is use double __ and this was something that we already covered take a look at the next
        # code
"""
    def __init__(self):
        self.__sideup = 'Heads'
"""
        # Something that we are going to be talking about here is how the __sideup is being updated here so basically
        # where we aer using the variable we are now using __sideup instead and thus we are just updating all the 
        # variables that are there and we make it a private variable that is important to understand when it comes to 
        # this code.

# %%
# This program imports the coin module and
# creates an instance of the Coin class

import coin

def main():
    # Create an object from the Coin class
    my_coin = coin.Coin()

    # Display the side of the coin that is facing up
    print("This side is up:", my_coin.get_sideup())

    # Toss the coin
    print("I am going to toss the coin ten times:")
    for count in range(10):
        my_coin.toss()
        print(my_coin.get_sideup())

# Call the main function
main()

#_________________________________________________________________________________________________________
# SUMMARY:
    # So here we are learning about modules as programs use more classes however the need to organize those classes
        # become greater. programmers ususally organize their class definition by storing them in modules then the
        # modules can be imported into any program that needs to use the classes they contain.
    # So here now you might be wondering what is going on here the very first thing that we did was that we stored the
        # Coin class in the coin module and the thing to know here is that the coin module is different from the Coin
        # class because the module is a file and then the class is what is going to be running the code 10 times and
        # now you might wonder why is that important when it comes to this code take a look at the next line...
"""
    my_coin = coin.Coin()
"""
        # so here we had created an object variable and then we call the coin file and then we called the Coin class
        # this is what is known as using modules to our advantage now the thing that you need to know here is that when 
        # it comes to this code what we could have done is wrote the class and then made an object to the class instead 
        # what we are doing is that we are making an object to the file or module and then to the class that we are 
        # trying to call and that is how we can access the get_sideup() function because to get here we need to get 
        # all the steps that are in between so this really means this look below...
"""
    obj_var = file/module.Class
"""
        # because of the self what happens is that we store data into the variable so we can call onto the functions 
        # that we prebuilt and they are holding their values in which we can store them.

# %%
# The BankAccount class simulates a bank account

class BankAccount:

    # The __init__ method accepts an argument for
    # the account's balance. It is assigned to
    # the __balance attribute.

    def __init__(self, bal):
        self.__balance = bal

    # The deposit method makes a deposit into the
    # account

    def deposit(self, amount):
        self.__balance += amount

    # The withdraw method withdraws an amount
    # from the account

    def withdraw(self, amount):
        if self.__balance >= amount:
            self.__balance -= amount
        else:
            print("Error: Insufficient funds")

    # The get_balance method returns the
    # account balance

    def get_balance(self):
        return self.__balance

#__________________________________________________________________________________________________________
# SUMMARY:
    # So here lets begin with what we know we know that we created a bankaccount module or file and in it we created
        # a class called BankAccount and within the class we have the __init__ here we are taking in the bal and the
        # other thing that we know is that we are using private variables meaning that no one can change these
        # variables so something that I wanted to know was that why is it sometimes we are using different variables
        # and I thought that it had to know with naming convention but then the idea came to me that maybe its like
        # when it comes to parameter and arguemnts where we dont have to follow a specific naming variables like the
        # parameter can reference one variable and the other variable can be named something different so here take a
        # look at this what we did was that we nammed __balance = bal and this was our private variable now the cool
        # thing about this code is that when using the self it carrys on so for example when you write this code you
        # are going to be thinking that the user is going to enter something in using the class and this is going to be
        # the spine init value meaning that its going to be user input that is later going to be carried down the next
        # thing that we are going to be doing is then we created this function called deposit and the cool thing is that
        # in it self we wrote the amount so when we call the deposit function we are putting in an amount value and that
        # is going to be the depoist amount the thing that I liked with this code was that the simplicty when it comes
        # to writing this code and then how it makes sense later on the next thing that we need to understand is that
        # when it comes to self_balance this the the init balance that we call in Class the differnce between putting an
        # arugment in the class vs putting an argument in the method and this is something that we already disccued but
        # how the variable is being used that plays an important factor you know when it comes to solving math problem
        # there is a part that is the constant vs being changed that is similar when it comes to working with this and
        # that is something that you need to know here so lets go back to the deposit and here we have the the constant
        # self.__balance which is the private variable that is storing the input from the user and you are adding the
        # deposit amount and the thing that I wanted to mention was that say you need to add amount to the init deposit
        # that we have then you are going to just call the method and then put in the amount that we wanted to add when
        # it comes to the stem or the root the next thing that we are foing to be talking about is the withdraw function
        # and here its a really simple statement now the amount is going to be the amount that the user wants to
        # withdraw that i something that we already covered but the cool thing is that we can have an insuffiencet error
        # meaning that we have to prevent that so in this case its going to be like this so for example its going to be
        # if 4000 the init we have and we removing the 200 then 4000 -= 200 else insuffienct error so this is everything
        # that made sense where I was like I know what is going on here the last thing that I wanted to talk about here
        # is the get_balance so something that came to my mind was that when it comes to this method what we are doing
        # is we are calling return self.__blance now something that was really smart was that when it comes to this code
        # we are always changing the value of the __balance when its greater then or less than the amount and subtract
        # and adding them but when we call the value its almost like saying this...
"""
    value = 10 - 4
    print(value)
"""
        # now this is a code that we have written many times but this is what the code is saying that print the value
        # after it has been changed and this is something that we are going to address in the code where we are doing
        # the whole adding and subtracting

# %%
# The program demonstrates the BankAccount class

import bankaccount

def main():
    # Get the starting balance
    start_bal = float(input("Enter your starting balance: "))

    # Create a BankAccount object
    savings = bankaccount.BankAccount(start_bal)

    # Deposit the user paycheck
    pay = float(input("How much were you paid this week? "))
    print("I will deposit that into your account.")
    savings.deposit(pay)

    # Display the pay
    print("Your account balance is $", format(savings.get_balance(), ",.2f"))

    # Get the amount to withdraw.
    cash = float(input('How much would you like to withdraw? '))

    print("I will withdraw that from your account.")
    savings.withdraw(cash)

    # Display the balance
    print("Your account balance is $", format(savings.get_balance(), ",.2f"), sep="")

# Call the main function
main()


#______________________________________________________________________________________________________________________
# SUMMARY:
    # So earlier we talked about how we can store the basic of our BankAccount code in the backened of the code and this
        # is something that we had leanred here when it comes to working with modules so here look what we are doing we
        # had created a BankAccount class where it was doing the depoist, withdraw, get_balance and this we had to put
        # a starting value the same is going on here but now all we are going to do is give arguements to the function
        # so take a look at this after we import the module on the top of the code we then get a starting balance and
        # this is going to be the building block of the __init__ method earlier we learned when it comes to working
        # with modules how we can store the class to module and import the module but we need to create an object to
        # the class and then the module that we want to use that is what is known as object oriented programming so in
        # this case since we have class called BanKAccount we can have another class called AccountRecievable and so
        # on and so forth and we can decide which class we want to create an object to and decide which methods we want
        # to run so lets take a look at the next line of code and there is a alot that is going on here but I wanted to
        # point out how important the next line of code is...
"""
    # Create a BankAccount object
    savings = bankaccount.BankAccount(start_bal)
"""
        # so take a look here we created an object variable and then we linked it to the odule called bankaccount and
        # then we linked it to the class that we chose in this case its going to be BankAccount class and then what we
        # did was that we put in the starting balance and this was going to be the init backbone spine so now you might
        # wonder what is going on here? like what is the reason for doing this and its really simple to be honest like
        # the reason why we do this is so that we can get starting balance and then what are you are doing is that you
        # are then init the argument that the person is storing and thus so now that is going to take place of the this
        # line of code in the bankaccount.py look below...
"""
    def __init__(self, bal):
        self.__balance = bal
"""
        # this line of code is the thing that we learned as the initializer and here we are getting the starting bal
        # and then putting the starting bal using the module and now the thing that you need to know is that the does
        # the method work different to the amount put in and the answer to that is really simple yes they are different
        # so take a look at the next code
"""
    def deposit(self, amount):
        self.__balance += amount
"""
        # so we talked about this code where we got the self.__balance which was private meaning that no one can change
        # up the code and this is proving how the other balance that we have is holding a value the initial value or the
        # starting balance now the thing that I want to cover in more detail is this...
"""
    savings =
"""
        # so this means that we are saving the the starting balance into this variable and we can then use this variable
        # that is going to be holding the init value and then run the method on it so take a look at the next code...
"""
    pay = float(input("How much were you paid this week? "))
    print("I will deposit that into your account.")
    savings.deposit(pay)
"""
        # here notice we are getting the pay variable and then we are running this with deposit method and here we have
        # a parameter and arguement value so the pay is being put here and its parameter is the amount and all we did
        # was that we added the init to the amount and something else that I wanted to highlight here was that when it
        # comes to this next line of code...
"""
        savings.deposit(pay)
"""
        # so this was something that I wanted to expand more on here and that was the savings variable .method and then
        # the argument so if someone wrote an init value at 10000 and then we ran the depoist method and put in say
        # 5000 then its going to be 10000 += 5000 but this goes back to the saving variable this is going to be holding
        # the init value or basically the starting value the next thing that we did was this line of code...
"""
    # Display the pay
    print("Your account balance is $", format(savings.get_balance(), ",.2f"))
"""
        # So here I wanted to cover an important concept so now we know what happened where we got the money and then
        # did an init value and then we ran the deposit method and what this did was that it had gotten a separate
        # variable and thus how it returns the value of self.__get_balance and how we said that its subtracting the
        # value and then reutning the new value kind of like a print statement. So here we learned how we can create 
        # an object variable that is holding the starting balance then we have the pay amount and this case its going 
        # to be saving.depoist(pay) we learned how  how when we call these methods we make parameters and arguements 
        # which are going to be storing the value in and that is something that we covered last time and then when
        # it comes to this we then learned how we created an a get balance function that job is to return something 
        # after a set amount and we then learnd how to create the object variable and to keep using that variable 
        # the thing that I didnt really cover was that when it comes to working with object variables how does the self 
        # work into poistion here and the answer to that is really simple what ends up going on is that self take the 
        # init value and then it modifys so when we use the method we are just printing the value of self but we need 
        # to use a method to access that value something else that I learned was taht we can use the object variable 
        # and then use the method and then we can do the whole formatting that is something that we need to know here 
        # so in essecne we are formatting the values and getting to the right decimal places.

# %%
# The BankAccount class simulates a bank account.

class BankAccount:

    # The __init__ method accepts an argument for the
    # account balance. It is assigned to the
    # __balance attribute.

    def __init__(self, bal):
        self.__balance = bal

    # The deposit method makes a deposit into the account

    def deposit(self, amount):
        self.__balance += amount

    # The withdraw method withdraws an amount from the
    # account

    def withdraw(self, amount):
        if self.__balance >= amount:
            self.__balance -= amount
        else:
            print("Error: Insufficent funds")

    # The get_balance method returns the
    # account balance

    def get_balance(self):
        return self.__balance

    # The __str__ method returns a string
    # indicating the object state.

    def __str__(self):
        return "The balance is $" + format(self.__balance, ',.2f')

#__________________________________________________________________________________________________________
# SUMMARY:
    # So we are going to be talking about what is the __str__ function here and quite often we need to display a message
        # that indicates an object state an object state is simply the values of the object attributes at any given
        # momment in the other code BankAccount class in the module bankaccount (different from bankaccount2) we had
        # a data attribute called __balance this will reference some value the value of the __balance attribute
        # represent the object state in the momment take a look at the next code...
"""
    # Get the starting balance amount
    start_bal = float(input("Enter your starting balance: "))

    # Create a BankAccount object
    savings = bankaccount.BankAccount(start_bal)

    account = bankaccount.BankAccount(1500.0)
    print("The balance is $", format(savings.get_balance(), ',.2f', sep="")
"""
        # so here the thing that I wanted to mention was that what we are doing is that we are creating an object
        # variable and what the object variable is going to do is that its going to init the 1500 into the stem and
        # in the print statement what we are doing is that we are getting the starting balance and then we are putting
        # the starting balance in an obj variable the next thing that I wanted to cover here is how the saving is
        # going to be the init value and then when we use methods with parameters we then have to pass in the arg in
        # this module where we call the function so there really is two parts to the code the first part is designing
        # the database in a way where it can take in parameters and then knowing when to take in parameters and then
        # when it comes desinging the module there we are going to call the method and then pass in an arguement from
        # there.
"""
    def get_balance(self):
        return self.__balance
"""
        # So here lets take a look at what is going on this whole code is a reference to this line here take a look at
        # the last line we know that savings is the init value and when we call the function we are going to be
        # returning the self.__balance so in essnece its more so of a call notice that we are not printing rather we
        # are returning and this whole process is known as returning an object state in other words what state the obj
        # is in so now displaying an object state is such a common task it is so common that many programmers equip
        # thier classes with a method that returns a string containing the object state and there is a special method
        # and that is called the __str__ method take a look at the next line of code and see how this code is different
        # from the code that you see above...
"""
    # The __str__ method returns a string
    # indicating the object state.

    def __str__(self):
        return "The balance is $" + format(self.__balance, ',.2f')
        
    vs.
    
    account = bankaccount.BankAccount(1500.0)
    print("The balance is $", format(savings.get_balance(), ',.2f', sep="")        
"""
        # So this code you might wonder what is the point of doing this? vs doing it the other way and take a look here
        # you can see that what we are doing is that we are calling the self.__balance directly now a little talk more
        # is that we are going to call a method called str and here we are returning the statement that is in the
        # beginning with the format specifier and then we return self.__balance here as well take a look at accounttest2
        # we will talk about this in more detail its easier to see something that I learned was that the __str__ method
        # also run in this instance..
"""
    account = bankaccount2.BankAccount(1500.0)
    message = str(account)
    print(message)
"""
        # so here the thing that you need to know is the account object is passed as an arg in the str function the
        # next part that you need to know is that this causes the BankAccount class __str__ method to be called the
        # string that is returned is assigned to the message variable then displayed by the print function in the third
        # line so from my understanding is that when we are running the str we are basically running the __str__ method
        # and this was something that was new to me where I was like wow I really didnt know that the most important 
        # thing that you can understand from this code is that when you mention the __str__ class on the init object 
        # then whats going to happen is when you call the object whatever the value that the object is holding its 
        # going to end up printing that value

# %%
# This program demonstrates the BankAccount class
# with the __str__ method added to it.

import bankaccount2

def main():
    # Get the starting balance
    start_bal = float(input("Enter your starting balance: "))

    # Create a BankAccount oject
    savings = bankaccount2.BankAccount(start_bal)

    # Deposit the user paycheck
    pay = float(input("How much were you paid this week? "))

    print("I will deposit that into your account.")
    savings.deposit(pay)

    # Display the balance.
    print(savings)

    # Get the amount to withdraw
    cash = float(input("How much would you like to withdraw? "))

    print("I will withdraw that from your account.")
    savings.withdraw(cash)

    # Display the balance
    print(savings)

# Call the main funtion
main()

#_______________________________________________________________________________________________________
# SUMMARY:
    # So here take a look at what is going on we are getting the starting bal and then using that as an argument for
    # our init value and overall the concept is really same we are then getting an arguement and then using that in
    # the deposit method that we created that is going to store the arguemnt and when we go back to the mainframe of
    # the function we created the parameter value as well that is going to be storing and reciveing the arguemnt and
    # thus does work with the data but the thing that I wanted to highlight here was this next part of the code and
    # that is...
"""
    # Deposit the user paycheck
    pay = float(input("How much were you paid this week? "))

    print("I will deposit that into your account.")
    savings.deposit(pay)

    # Display the balance.
    print(savings)
    
    # Because of this we are able to do the code that you see above.
        
    def __str__(self):
    return "The balance is $" + format(self.__balance, ',.2f')
"""
    # So the thing that I was thinking was that say if the value of self.__balance is over-ridden how is that going to
    # affect the code is it still going to print the thing that we want it to print and the answer to that is really
    # simple yes notice when we call print savings so when we are calling the print(savings) what this is doing is that
    # its going to be printing what we see on the str that really is all that you need to know tbh that instead of 
    # having call the obj variable and then the function what we are doing is just printing the obj variable becasue 
    # that is holding a part of the self.__balance one thing that I like about this approach is that it makes the code 
    # more cleaner to read and cleaner to write instead of having to write with each functions we can just write it 
    # with the obj variable

# %%
def has_no_return():
    pass

has_no_return()
print(has_no_return())

#_____________________________________
# SUMMARY:
    # So this is a simple code that we know here but the thing that I wanted to focus on was that when I was writting
        # this other code I was getting none and I was wondering to myself what does none mean? and none is something
        # that I have seen a lot so this time I was wondering why I was getting it and take a look at this we created
        # a function that is called has no return meaning that since it is passed and is empty that means it has nothing
        # in it we then call the function and then we print the result we get none so the other code that I was
        # writting the reason why it was saying none was because the code was empty

# %%
class Person:

    def __init__(self, name, age):
        self.name = name
        self.age = age

    def myfunc(self):
        print("Hello my name is", self.name)
        print("My age is", self.age)

p1 = Person("John", 36)
p2 = Person("Jackie", 17)

print(p1.name)
print(p1.age)

p1.age = 59

print(p1.age)

p1.myfunc()
p2.myfunc()
#____________________________________________________________________________________________
# SUMMARY:
    # So before we begin this code we need to understand that we are creating a class called Person and then we are
        # creating an object called p1 and this is what it comes to the the blueprint vs the houses that come from the
        # blueprint we started an init function and here we took two values and they are the name and age we set them
        # to each other so that they can be initialized. All classes have a function that is called __init__ which is
        # always executed when the class is being initiated we use the __init__ function to assign values to object
        # properties or other operations that are nesseccary to do when the object is being created the __init__
        # function is being called automatically every time the class is being used to create a new object and then we
        # learned how we can create that new object and then it acts as our self parameter the thing that I wanted to
        # also mention here was that the mistake that I was making here was here take a look...
"""
    p1.myfunc()
    p2.myfunc()
"""
        # the thing that I wanted to iterate here was that the mistake that I was making was that instead of using the
        # object.method what I was doing was that I was using this appraoch print(object.method) and that is something
        # that I didnt need to call instead what I needed to do was that I just use the object and its method that was
        # an error that I had made when I wrote this code.
"""
    p1.age = 59
"""
        # we also learned how to modify objects take a look here and notice what is happening we are calling the obj
        # variable and then calling the method and changing the number in this case we are chaing it to 59
"""
    del p1.age 
    del p1
"""
        # This is used to delete the age that the user sets and the second thing is used to delele the p1 the object
        # variable that the user writes.
"""
    class Person:
        pass
"""
        # class definiton cannot be empty but if you for some reason have a class definition with no content put in a
        # pass statement to avoid getting an error.

# %%
# This program imports the simulation module and
# creates three instances of the Coin class

import coin

def main():
    # Creates three object from the Coin class
    coin1 = coin.Coin()
    coin2 = coin.Coin()
    coin3 = coin.Coin()

    # Display the side of each coin that is facing up
    print("I have three coins with these sides up:")
    print(coin1.get_sideup())
    print(coin2.get_sideup())
    print(coin3.get_sideup())
    print()

    # Toss the coin
    print("I am tossing all three coins...")
    print()
    coin1.toss()
    coin2.toss()
    coin3.toss()

    # Display the side of each coin that is facing up.
    print("Now here are the sides that are up:")
    print(coin1.get_sideup())
    print(coin2.get_sideup())
    print(coin3.get_sideup())

# Call the main function
main()

#__________________________________________________________________________________________________
# SUMMARY:
    # So this code is really easy to understand but before we begin to decipher this code down we need to go back and
        # and check to see the coin module so we begin with the Coin class and then we call the __init__ function here
        # and we set the __sideup a private variable to 'Heads' and then we made a toss function something that I
        # wanted to cover in more detail was this...
"""
    random.randint(0, 1) == 0
"""
        # here this was new for me when it comes to writting random.randint normally what I use is storing this in a
        # variable and thus it made sense to do so but this is a newer way of writting where its really not stored to
        # a variable or anyhting and then set == 0 so that way if it is equal to 0 then its going to be following the
        # if clause and otherwise it is going to be following the else clause so lets take a look at the next code here
"""
    # Creates three object from the Coin class
    coin1 = coin.Coin()
    coin2 = coin.Coin()
    coin3 = coin.Coin()
"""
        # here we had created 3 coin objects and we then called the coin module and the Coin class and thus going back
        # to the notes taht we covered we had init the value with 'Heads' so now each coin is object is going to be
        # referencing Heads another detail momment that we learned in this code was that when it comes to this is that
        # each coin object has its own __sideup attribute something that I wanted to empahsis on here was that when it
        # comes to this code
"""
    # Display the side of each coin that is facing up
    print("I have three coins with these sides up:")
    print(coin1.get_sideup())
    print(coin2.get_sideup())
    print(coin3.get_sideup())
    print()
"""
        # the next thing that we are doing is that we are calling the get_sideup() method and to understand this better
        # what we are doing is that we are just printing what is in our init value the thing that I wanted to emphasis
        # on here was how this can be used to get on all three diferent object the point that this code is trying to
        # make is how we can call the init values that have been preset to Heads on each objects when we call the
        # function called get_sideup()
"""
        # Toss the coin
    print("I am tossing all three coins...")
    print()
    coin1.toss()
    coin2.toss()
    coin3.toss()
"""
        # notice how we are tossing each coin we call the object and then run the toss method on it and thus doing so
        # what happens is that we end up running this method on all the objects that we made and what this does is 
        # similar to the other code we did where the init is going to change depending on what random.randint is going 
        # to do the point that this code is trying to make is that how the init value changes one each object.

# %%
# The CellPhone class holds data about a cell phone

class CellPhone:

    # The __init__ method initializes the attributes

    def __init__(self, manufact, model, price):
        self.__manufact = manufact
        self.__model = model
        self.__retail_price = price

    # The set_manufact method accepts an argument for
    # the phone manufactuer

    def set_manufact(self, manufact):
        self.__manufact = manufact

    # The set_model method accpets an arguement for the
    # phone model number.

    def set_model(self, model):
        self.__model = model

    # The set_retail_price method accepts an argument
    # for the phone retail price

    def set_retail_price(self, price):
        self.__retail_price = price

    # The get_manufact method returns the
    # phone manufactuerer

    def get_manufact(self):
        return self.__manufact

    # The get_model method returns the
    # phone model number

    def get_model(self):
        return self.__model

    # The get_retail_price method returns the
    # phone retail price.

    def get_retail_price(self):
        return self.__retail_price

#________________________________________________________________________________________________________________
# SUMMARY:
    # So here is what is going on we are designing a program to manage cell phone that are in inventory we have been
        # asked to design a class that represents cell phone so lets begin with what we know first and foremost we have
        # the __init__ and here this is going to be the backbone of the class meaning that whatever object that we
        # create we are going to be using the manufact, model, price and we set them to a private self variable meaning
        # that these values cannot be changed if we were to call the private self variable and try to change it manually
        # it wont work the next thing that I wanted to talk about when it comes to working with obj programming we are
        # working with the get and set methods take a look...
"""
    def set_manufact(self, manufact):
        self.__manufact = manufact

    def set_model(self, model):
        self.__model = model

    def set_retail_price(self, price):
        self.__retail_price = price
"""
        # so take a look now this is self explantory but what is happening is that we made a function called
        # set_manufact(self, manufact) and here what we did was that say we created an object variable and called the
        # method we then pass in an argument and this is going to change the name of the model and something that I
        # wanted to make mention here was that when it comes to this code earlier we talked about how when it comes to
        # changing the manufact and then the model and then the retail price we cant becasue the variable are private
        # well yea that is true we cant change them directly we can change them indirectly with the use of methods to
        # override them because what we need to know is that when we call the class function and then set the each of
        # the parameter the thing that I wanted to focus on here is that what we can do is use the obj_var.method(oa)
        # meaning oa = overide argument these method we really didnt use in this...
"""
    def get_manufact(self):
        return self.__manufact
    
    def get_model(self):
        return self.__model

    def get_retail_price(self):
        return self.__retail_price
"""
        # something that I wanted to expand on here was that we are using the get methods more then we are using the
        # set methods and the thing that I wanted to iterate on it was that and they are doing something really simple
        # but take a look at the next output this explains the code more better...
"""

    # Create an instance of the Cellphone class
    phone = cellphone.CellPhone(man, mod, retail)

    # Display the data that was entered.
    print("\nHere is the data that you entered:")
    print("Manufacturer:", phone.get_manufact())
    print("Model Number:", phone.get_model())
    print("Retail Price: $", format(phone.get_retail_price(), ',.2f'), sep='')

    __________________________________________________
    Enter the manufacturer: Wayne Enterprise 
    Enter the model number: T-9082
    Enter the retail price: 199.20
    
    Here is the data that you entered:
    Manufacturer: Wayne Enterprise 
    Model Number: T-9082
    Retail Price: $199.20
"""
        # So this is what I wanted to expand on here so first what we did was that we got the manufact and then the
        # model number and then the retail price we then created an object variable that is going to be calling the
        # module.class(parameter, parameter, parameter) and this stuff is really nothing new the point that I wanted to
        # emphasis on here is that notice how we are using the get mostly another detail mommnet is that since we dont
        # have a parameter value displayed in the get method that means that we are going to be using the object
        # parameter value that we have already defined and that is something that we need to know becuase when we label
        # a parameter value along with an arguement value we then have to specify each parameter so that it is even and
        # thus here what we are doing is that we are returning the manufact, model, retail_price the one thing that I
        # was suprised about here is that when it comes to this code is that when we use the return statement with the
        # string what happens is that when we print out the statement whatever is stored that thing gets returned and
        # that is somewhat new because earlier what we have been doing is making a function that is returning the thing
        # that we typed in looking back to the other code what had happened was that we were using this but this was 
        # something that I really didnt into notice until this code

# %%
# This program tests the CellPhone class

import cellphone

def main():
    # Get the phone data.
    man = input("Enter the manufacturer: ")
    mod = input("Enter the model number: ")
    retail = float(input("Enter the retail price: "))

    # Create an instance of the Cellphone class
    phone = cellphone.CellPhone(man, mod, retail)

    # Display the data that was entered.
    print("\nHere is the data that you entered:")
    print("Manufacturer:", phone.get_manufact())
    print("Model Number:", phone.get_model())
    print("Retail Price: $", format(phone.get_retail_price(), ',.2f'), sep='')

# Call the main function
main()

#_______________________________________________________________________________________________
# SUMMARY:
    # Something that I wanted to mention here was that when it comes to this code we are making an object variable and
        # then setting the parameters but here is the catch we are getting the input from the user that is something that
        # I wanted to address that was new here and then all we are doing is we are returning this value and thus we get
        # it to print out using the get functions that we created and also notice the format specifier that we are using as
        # well
    # Some general notes from the book, it is common practice to make all of a class data attributes private and to
        # provide public methods for accessing and changing those attributes this ensures that the object owning those
        # attributes is in control of all the changes that being made to them. A method that returns a value from a
        # class attribute but does not change it is known as an accessor method accessor methods provide a safe way
        # for code outside the class to retrive the value of the attribute without exposing the attributes in a way that
        # they could be changed by the code outside the method so the get methods are accessors method they are used to
        # get data but dont really change the data
    # A method that stores a value in a data attribute or changes the value of a data attribute in some other way is
        # known as mutator method mutator methods can control the way that a class data attributes are modified when a
        # code outside the class needs to change the value of an objects data attribute it is typically calls a mutator
        # and passes the new value as an arguement if nesseccary the mutator can validate the value before it assigns
        # it to the data attribute so the set methods are known as mutator methods.
    # Mutator methods are sometimes called setters and accessors methods are sometimes called getters

# %%
# This program creates five CellPhone objects and
# stores them in a list

import cellphone

def main():
    # Get a list of CellPhone objects.
    phones = make_list()

    # Display the data in the list
    print("Here is the data that you entered:")
    display_list(phones)

# The make_list function gets data from the user
# for five phones. The function returns a list
# of CellPhone objects containing the data

def make_list():
    # Create a empty list
    phone_list = []

    # Add 5 CellPhone objects to the list.
    print("Enter data for five phones.")
    for count in range(1, 6):
        print("Phone number " + str(count) + ":")
        man = input("Enter the manufacturer: ")
        mod = input("Enter the model number: ")
        retail = float(input("Enter the retail price: "))
        print()

        # Create a new CellPhone object in memory and
        # assign it to the phone variable
        phone = cellphone.CellPhone(man, mod, retail)

        # Add the objects to a list
        phone_list.append(phone)

    return phone_list

# The display_list function accepts a list containing
# CellPhone objects as an arguement and display the
# data stored in each object

def display_list(phone_list):
    for item in phone_list:
        print(item.get_manufact())
        print(item.get_model())
        print(item.get_retail_price())
        print()

# Call the main function
main()

#_______________________________________________________________________________________________________
# SUMMARY:
    # So this code is really cool because it is teaching us some new concepts and this is something that I wanted to
        # talk about here first we are importing cellphone module that is the first thing that we need to know the
        # second thing that we did was that we created an object variable that is bein/x g set to the make_list function
        # and the second function that we made is called the display_list function and what it is taking in is going
        # to be phones list this goes back to our notes on classes and method stuff that we have already covered the
        # second thing that I wanted to talk about here is called the make_list function look down below...
"""
def make_list():

    # Create a empty list
    phone_list = []

    # Add 5 CellPhone objects to the list.
    print("Enter data for five phones.")
    for count in range(1, 6):
        print("Phone number " + str(count) + ":")
        man = input("Enter the manufacturer: ")
        mod = input("Enter the model number: ")
        retail = float(input("Enter the retail price: "))
        print()

        # Create a new CellPhone object in memory and
        # assign it to the phone variable
        phone = cellphone.CellPhone(man, mod, retail)

        # Add the objects to a list
        phone_list.append(phone)

    return phone_list
"""
        # Lets break down what is going on here what we did was that we started a for loop that is going to iterate
        # a total of 5 times the thing that I wanted to highlight was that why did we do it this way its really simple
        # we are trying to get each iteration therefore we started the iteration at 1 and its going to end at 5 the
        # second thing that we did was that we got the manufacturer, model number, retail price each time from the user
        # and the thing that we need to know is that this is going to be going into the class that we created in the
        # module take a look at the next line of code and it all makes sense...
"""
    # phone = cellphone.CellPhone(man, mod, retail)
"""
        # Now this code is something that we already have covered plenty of times the thing that I wanted to mention
        # here was that when it comes to this code we can use each object variable in a for loop so we know that this
        # loop is going to be going 5 times and we are gathering data (something that I forgot to cover is the
        # phone_list this is going to be holding an empty list) what we are doing is we are adding each object to a list
        # and thus returning the list so in order to ellaborate more on this the thing that I wanted to say was that
        # visualize what is going on here so how are each object stored in the list...
"""
    Phone number 1:
    Enter the manufacturer: apple 
    Enter the model number: a-111
    Enter the retail price: 1000
"""
        # So here this is something that I wanted to talk about here and it pretains to the make_list function as you
        # can see here we are getting each input from the user and this is going to act in the argument value that we
        # have labeled for our class using that module and accessing the __init_ that is something that we already know
        # of what is going on the thing comes to how it is stored in the list and this part makes it more clear...
"""
    # Add the objects to a list
    phone_list.append(phone)
"""
        # notice the empty list that we made and then we append each of the object variable that we created the thing
        # to know is that this is going to iterate a total of 5 times and each iteration is going to be taking in a
        # different manufacter, model number, retail price value so in 1 iteation its going to store different values
        # compared to the second iteration and why is that important its going to make sense in the second part of the
        # code the last thing is that we are returning the list that is going to be going to be used as the obj variable
"""
     for item in phone_list:
        print(item.get_manufact())
        print(item.get_model())
        print(item.get_retail_price())
        print()
        
    using these functions
    _____________________________________________
    def get_manufact(self):
        return self.__manufact

    def get_model(self):
        return self.__model
    
    def get_retail_price(self):
        return self.__retail_price
"""
        # So here lets take a look at whats going on this is going to make things more clear we then use a for loop
        # in the phone list that we made and we know that each iteration is not holding three values and this case its
        # going to be looking like this...
"""
    apple 
    a-111
    1000.0
"""
        # this is how its being stored in the list but remember these are not just randomly stored these are from the
        # init value that is something important to consider the best way to understand this is this so once we get
        # each index we can use that as the object because what is happening is that the list is storing the objects
        # therefore we can use the uno refeverse card to get the obejct and then call the method this is something that
        # we have been doing all the time
    # notes from the book "This program gets the data for five phones from the user creates five CellPhone objects
        # holding the data and store those objects in a list it then iterates over the list displaying the attributes
        # of each object" & " the for loop iterates five times each iteration it gets the data for a cell phone from
        # the user it creates an instance of the CellPhone class that is initialized with the data and then adds the
        # data objects to list the display_list function accepts a list of CellPhone object as arguments it loops over
        # each obj and displays the attributes but that was something that I found to be interesting how we can use the 
        # for loop and then we can use the method that we want to run my hypothsis is this that the naming convention 
        # acts as a vessel meaning that we need to understand that we are using object to store attributes so its 
        # important to understand at each index we are storing a set of values and then when we use a for loop that is 
        # going to loop thru the list in each iteration the ways the values are stored they are then recalled using the 
        # methods that we set that is a lot to digest but it makes sense that you can store objects into list and then 
        # use for loops to loop thru the list and get each object value but remmber what you do for one you must do for 
        # all that is an important case to understand when it comes to working with this code.

# %%
def cube(num):
    return num * num * num

result = cube(5)
print(result)
print(cube(4))

#_________________________________________________________________________
# SUMMARY:
    # So I learned a lot when it comes to the return statement and the thing that caught my attention here was that
        # when it comes to this code its really simple but what I did was that I made a function called cube and here
        # I specified a parameter called num and then what I did was that I said that return the value of num times
        # itself 3 times and look where it says result = cube(5) something that I had learned about this code is that
        # at first I was wondering the guy did this where he had called the function and passed something in and this
        # showed that I am still learning the concept because I was wondering to myself that how are they going to pass
        # anything and its simple when you created a functiona and put the variable that really it and another thing
        # that I had learned here was that when it comes to this code when you just said return and for the function
        # had you passed in any argument then it wouldnt say anything and if you said...
"""
def cube(num):
    num * num * num

cube(3) 
print(cube(3))
"""
        # so this code was relly simple to understand here but this was the mistake that I was making I was multiplying
        # num * itself 3 times and that wasnt the problem but when I typed in cube(3) it was giving me an empty terminal
        # and when I typed in print(cube(3)) it gave me none and I was wondering to myself why is this thing giving me
        # none and didnt really understand why it became really simple to understand later on what I had to do was to
        # use the return and then use the print statement
"""
result = cube(5)
print(result)
"""
        # So this code is really simple to understand what we are doing here is that we are calling the function and
        # and then storing it to variable and then printing that variable something else that I wanted to mention here
        # was that when it comes to this code if you mention anything after return it then does not get registered here
        # so meaning that the code emptys out the function simialr to a break statement that hey this is a dead end
        # in the road that was useful information here.

# %%
# This program passes a Coin object as
# an arguement to a function
import coin

# main function
def main():
    # Create a Coin object
    my_coin = coin.Coin()

    # This will display 'Heads'
    print(my_coin.get_sideup())

    # Pass the object to the flip function
    flip(my_coin)

    # This might display 'Heads' or it might
    # display 'Tails'
    print(my_coin.get_sideup())

# The flip function flips a coin.
def flip(coin_obj):
    coin_obj.toss()

# Call the main function.
main()

#_________________________________________________________________________________________________________________
# SUMMARY:
    # So this is going to be talking about passing objects as Arguements when you are developing applications that work
        # with objects you often need to write functions and methods that accepts objects as args so lets talk about
        # what is going on here first we started off by creating a coin object take a look here...
"""
    # Create a Coin object
    my_coin = coin.Coin()
"""
        # so here we already learned what is going on we created imported the module and then we imported the Coin
        # class and then we created the object now we already know that the object variable is going to be holding the
        # __init__ value so lets take a look at what the object variable is holding something that I wanted to mention
        # that I was not really paying any attention to here was that when we create the class what happens is that we
        # get that means we can use the methods that we find within the class so any functions that are made in the
        # class such as the toss() and the get_sideup() that was an important point that I really didnt consider when
        # writting this code what I was thinking was that oh we are using the init value but then I understood wait a
        # minute we also have two different functions within the init value and we know that each of the function are
        # using the access to the spine or meaning the init so here are some general rules of thumb when you pass in
        # an object as an argument that thing that is passed into the parameter variable is a reference to the object
        # as a reuslt the function that recieves the object as an arguement has access to the actual object so that is
        # why we were to able to call the get_sideup() function that was within our class because it had access to the
        # self parameter that was being used in our init value and how we learned that when put in an paramter that
        # is an idication that we want to fill that parameter with something so here since we didnt really fill it with
        # anything that meant that we are trying to fill it ourself
"""
    # Pass the object to the flip function
    flip(my_coin)
"""
        # So lets take a look here notice what is happening this is simialr to the list thing that we did where we
        # created a list and then passed in the object variable now the thing that I wanted to mention was that when it
        # comes to this code now its important to understand what is going on here in my opinion its really simple...
"""
    # The flip function flips a coin.
    def flip(coin_obj):
        coin_obj.toss()
"""
        # Take a look here this part of the code makes it really simple to understand so what we did was that we
        # created a function that is called flip and then we put in a parameter value back in the main function what we
        # did was that we created the flip function and passed in an argument and thus what had happend was that arg
        # was then going to be the thing that this code is trying to stress is how objects can be communicated with
        # different functions and now lets talk more in depth of what is going on here what we did was we used that
        # parameter value that is holding our object and then we called the function that is within our class now the
        # thing that I wanted to stress was that since I am using the module.class() when I use the object variable I
        # can then use whatever is in the class any functions that I want to get what I want because of the __init__
"""
    # This might display 'Heads' or it might
    # display 'Tails'
    print(my_coin.get_sideup())
"""
        # So lets take a look at what is going on here there was something that I wanted to stress on this here was
        # that we know that since we are using the object variable and then using the module what this is doing is that
        # its going to be returning the sideup and we talked about how here it makes sense where when you are using
        # return what it does that it returns the value and in this case since it is close to the __init__ value that
        # means that its just returning the __sideup something that I wanted to talk about here is how this code is all
        # working in summary and the answer to that is really simple we created the object variable then we called
        # which side the coin is facing up and this case it is going to be Heads and the second thing that we did was
        # we called the flip method and now this is taking our object variable that is basically reffering to the init
        # and then what we did was that in that function we called the toss function and this is going to be tossing the
        # coing and then we called the get_sideup.

# %%
# This program pickles CellPhone objects
import pickle
import cellphone

# Costants for the filename
FILENAME = 'cellphones.txt'

def main():
    # Initialize a variable to control the loop.
    again = 'y'

    # Open the file.
    output_file = open(FILENAME, 'wb')

    # Get data from the user.
    while again.lower() == 'y':
        # Get the cellphone data.
        man = input("Enter the manufacturer: ")
        mod = input("Enter the model number: ")
        retail = float(input("Enter the retail price: "))

        # Create a CellPhone object.
        phone = cellphone.CellPhone(man, mod, retail)

        # Pickle the object and write it to the file.
        pickle.dump(phone, output_file)

        # Get more cell phone data?
        again = input("Enter more phone data? (Y/N): ")

    # Close the file.
    output_file.close()
    print("The data was written to", FILENAME)

# Call the main function
main()

#_______________________________________________________________________________________________________
# SUMMARY:
    # So here take a look at this we are importing the pickle module and then we are importing the cellphone module
        # something that I wanted to mention here was that we used the naming constant called FILENAME and this one
        # is storing the file the thing that I found cool was that this was a first and it made writting the code more
        # easier where I was just using the naming constant a detail momment is the naming constant is outside the
        # block meaning that it is easily accessible the second thing that we did was that we open the file and in wb
        # mode which is write bytes mode everything else is really simple where we do the whole its equal to Y then do
        # this but once again we are getting the manufacter, model, retail_price and then we create an object variable
        # that is holding each object that we create using the class meaning that the cookie cutter that we use we are
        # going to be creating objects from the same thing now I finally get it so each object that we are creating
        # what we are going to be doing is then dumping that into the output file variable now something else that I
        # want you to understand is that isntead of using the FIlENAME to dump we are dumping to the obj variable and
        # the thing to understand here is check the next line of code...
"""
  # Pickle the object and write it to the file.
        pickle.dump(phone, output_file)
"""
        # notice how we are using output file now to understand that is that when we used the open module we then used
        # wb mode and what this did was that it was able to choose the file and then write the bytes to the file so
        # that is why we are using the phone which is going to be the object and then the file location of where and
        # how it should go that is something important that you need to know and another thing is that this code is
        # teaching that the objects that you create you can dump them into the file that we create that shows us how
        # the code can be used interchangably we then close the file and then write where the data was written to.
        # Notes from the book the pickle module dump function serailizes (pickles) an object and writes it to a file
        # and the load function retrieves an object from a file and deserializes (unpickles it) you can also pickle and
        # unpickle objects of your own classes this program pickles three CellPhone objects and saves them to a file
        # and the next program retrives those objects from the file and unpickles it.

# %%
# This program unpickles CellPhone objects
import pickle
import cellphone

# Constants for the filename
FILENAME = 'cellphones.txt'

def main():
    end_of_file = False         # To indicate end of file

    # Open the file.
    input_file = open(FILENAME, 'rb')

    # Read to the end of the file.
    while not end_of_file:
        try:
            # Unpickle the next object.
            phone = pickle.load(input_file)

            # Display the cell phone data.
            display_data(phone)
        except EOFError:
            # Set the flag to indicate the end
            # of the file has been reached
            end_of_file = True

    # Close the file
    input_file.close()

# The display_data function displays the data
# from the CellPhone object passed as an argument
def display_data(phone):
    print("Manufacturer:", phone.get_manufact())
    print("Model Number:", phone.get_model())
    print("Retail Price: $", format(phone.get_retail_price(), '.2f'), sep='')
    print()

# Call the main function
main()

#__________________________________________________________________________________________________
# SUMMARY:
    # So take a look here what we are doing is that we are going to be reading the from the file that we made so the
        # first thing that we need to know here is taht the end_of_file = False we started off with a flag here now
        # this was good because what it had done was that it had retouched up on our knowledge of flags here and that
        # was that when we use this take a look below...
"""
    end_of_file = False         # To indicate end of file
    
    while not end_of_file:
"""
        # so take a look at what is happening here we set the flag to False that is something that we knew the second
        # thing is that what we did was that we used the while not end_of_file and what this is saying is that we know
        # that end_of_file is going to be set to True in terms when we are saying that while not end_of_file what we
        # are saying is that while False now I know what you might be wondering wait a minute that does not make any
        # sense why are we setting a flag value to False and then saying that it is True and then using the not and to
        # counter this point here the thing that I knew is that when we are saying that while not end_of_file the best
        # way to understand is taht end_of_file is set to True but prior we set it to false other wise we are saying
        # while not False and that means True and the except why are we saying True? then shouldnt it be the oppsite
        # False it doesnt make sense for us to do that
    # So once we open the file in rb mode this is going to let us read from the file that we pickled the data the
        # second thing that we did was that here...
"""
    while not end_of_file:
        try:
            # Unpickle the next object.
            phone = pickle.load(input_file)

            # Display the cell phone data.
            display_data(phone)
"""
        # so this was something that I wanted to ellobrate more on here this is saying that while false and then we say
        # while not True it means false and the first end_of_file acts similar to the pretest variable meaning that it
        # gives the first iteration to run its no different from saying y and while not == y or something like that here
        # so here we are running while false so therefore the try caluse is going to run here and then we create an obj
        # variable that is gooing to to...
"""
    # Unpickle the next object.
    phone = pickle.load(input_file)
"""
        # here its going to be creating an object variable called phone and then its going to call the pickle module
        # and the load function and then we are putting in the file that we are reading from to understand this code
        # more better we need to understand this part of the code more better...
"""
    # Create a CellPhone object.
    phone = cellphone.CellPhone(man, mod, retail)

    # Pickle the object and write it to the file.
    pickle.dump(phone, output_file)
"""
        # this is from the pickle_cellphone and what we did was that we created an object and then dumped each object
        # to the file that we want that is an important thing to understand when writting this code the second thing to
        # know here is that how does this imapct the code that we have here? the first and foremost here is that we are
        # writting an object to the file that we want the second thing is that we are loading straight from the file
        # and then storing it directly to the object the one thing that I wanted to address here is how does the code
        # know that its reading all the init values we know the way that they are stored where we get the each init from
        # the user well how are they retrieved from the file? and take a look here...
"""
    # Display the cell phone data.
    display_data(phone)

    def display_data(phone):
        print("Manufacturer:", phone.get_manufact())
        print("Model Number:", phone.get_model())
        print("Retail Price: $", format(phone.get_retail_price(), '.2f'), sep='')
        print()
"""
        # this is the giveaway of what is going on and take a look at the display function here we are taking in the
        # phone parameter and in the try function we specifed the argument here and thus doing so what happens is that
        # the object is going into the function and then that function is calling on the methods that are in the class
        # and we use that object_reference.method() to get what we want to search for the second thing that we want to
        # look at here is this...
"""
    except EOFError:
        # Set the flag to indicate the end
        # of the file has been reached
        end_of_file = True
"""
        # here is something that I wanted to address more here and this is what we call an EOFError here if we run into
        # this then the while loop is going to terminate because we said that hey end the loop and that is why we set
        # the flag to True here that indicates that this loop is getting to an end so the most important thing to
        # understand in this code is that when loading the file you are storing it into an object and thus then we are
        # taking it a function that is then going to sort out thru using the methods that is an important point to
        # understand here. the book goes on and says that this program retrives those objects from the file and then
        # unpickles it so the standard procedure to retrive object is to call up on the file and load it using the
        # pickle load and then storing it to object that clears the misconception of wheter this is a certain way in
        # which this is now a certain way Something that I wanted to mention here is that when it comes to this code
        # notice a key difference we didnt do the whole module.class(arg, arg, arg) and then set that to be input
        # variable and thus we gather the input but that is a key difference when it comes to writting you have to
        # specify the all this and when it comes to reading you can read the file and store it to an object my theory
        # is this what happens is that we read the whole file because rb the data is being read and then stored to the
        # object we know this is what the file is reading take a look here...
"""
���       �	cellphone��	CellPhone���)��}�(�_CellPhone__manufact��ACME Electronics��_CellPhone__model�
�M1000��_CellPhone__retail_price�G@h��z�Hub.���        �	cellphone��
"""
        # here the thing that I wanted to mention was that notice what this is saying that the cellphone module and then
        # the CellPhone class and then the name of the functions which is retail_price model and manufact here that is 
        # the important thing to understand here that is why we can use the object variable to call the function because
        # the class and module are already stored in it and that is something that you need to know something that I 
        # really didnt think to deep in

# %%
class Book():

    fav_book = []

    def __init__(self, title, pages):
        self.title = title
        self.pages = pages

    # def is_long(self):
    #     if self.pages > 100:
    #         return True
    #     return False

    def __str__(self):
        return f"{self.title} is {self.pages} pages long"

book = Book("Are you my mother?", 72)
book2 = Book("The Digging-est Dog", 72)

Book.fav_book.append(book)
Book.fav_book.append(book2)

for b in Book.fav_book:
    print(b)

#________________________________________________________________________________________________
# SUMMARY:
    # So this code was really simple to understand lets examine what is going on here we started off with an empty list
        # we then had the __init__ where we are getting the title and pages the is long method we really arent using
        # much but this code is teaching more when it comes to using the __str__ method which is going to be invoking
        # the STRING REPRESENATION EACH TIME WE CREATE AN OBJECT that is really important to understand when we write
        # this code so lets takae a look at the objects that we created they are called book and book2 and here they
        # are taking in two arguements one is called the title and the other is called the pages so what this is really
        # doing is simple its putting the one for the title and the other for the pages and then its just printing the
        # message that really all it is for so each time we fill out the object variable with the given parameters we
        # dont have to call the display method we can just use this and it prints the message now I finally get what is
        # going on with this the next thing that I wanted you to understand was that we are creating a list and then
        # adding each object in so we did this approach take a look...

"""
    Book.fav_book.append(book)
    Book.fav_book.append(book2)
"""
        # take a look at what is going on here notice what we are doing we are calling the class module and then calling
        # the list and then append function and the name of the object that we want to append that is something
        # important to understand when it comes to this code and it makes sense as to why it is this way because the
        # thing that we need to be aware of here is that the list is in our class so we need to call the class the list
        # and so on and so forth take a look at the next line of code...

"""
    for b in Book.fav_book:
        print(b)
"""
        # notice how we are looping through our list we are calling the class and then calling the list and then print
        # b that is a really important point to understand when it comes to this code this shows that to access any
        # thing within our class we are going to be using the class even when it comes to simple looping now this is
        # really new because we are used to looping through our list so easily and now what we are doing is looping
        # through using the class and then what we want and we just go and print each object...
"""
    Are you my mother? is 72 pages long
    The Digging-est Dog is 72 pages long
"""
        # This is what the code is going to be doing we are going to be storing each object to list and then print out
        # it out and the best way to understand this is that each object contains the parameter and arg so therefore 
        # what we are doing is that when we are storing the object we are acutally not really looking at the object 
        # rather the object acts as the vessel to the parameter and arguement so what we really need to focus on is the 
        # self that is really important point to consider when writting this code down.

# %%
# The contact class holds contact information

class Contact:
    # The __init__ method initializes the attributes
    def __init__(self, name, phone, email):
        self.__name = name
        self.__phone = phone
        self.__email = email

    # The set_name method sets the name attribute.
    def set_name(self, name):
        self.__name = name

    # The set_phone method sets the phone attribute.
    def set_phone(self, phone):
        self.__phone = phone

    # The set email method sets the email attribute.
    def set_email(self, email):
        self.__email = email

    # The get_name method returns the name attribute.
    def get_name(self):
        return self.__name

    # The get_phone method returns the phone attribute.
    def get_phone(self):
        return self.__phone

    # The get email method returns the email attribute.
    def get_email(self):
        return self.__email

    # The __str__ method returns the objects state
    # as a string
    def __str__(self):
        return "Name: " + self.__name + \
            "\nPhone: " + self.__phone + \
            "\nEmail: " + self.__email

#________________________________________________________________________________________________________
# SUMMARY:
    # Some recap notes here to understand earlier we learned about how to use dictionaries and how they store key and
        # value pairs the next code that we are going to decipher is going to be using that concept and then using the
        # object oriented approach into understanding this some general notes if you want to specify the a specific
        # value when it comes to using dict you need to use its key we saw examples how it stored values such as stings
        # integers, floating point number, list, tuples in dicts dict are also usefule for storing objects that you
        # create from your own classes. The program that we are going to create here keeps contacts information such as
        # names, phone numbers, and email address, you could start off by writting a Contact class and then an isntacne
        # of the class keeps the data that you see above so first we learned how the __init__ has the name, phone, email
        # the next thing that we are doing is we are setting up our setters and then setting up our getters for the set
        # - ters we know that we are going to be getting the input that is why we need to specify the parameter and
        # when it comes to our getters all we are doing is we are returning what is in our init the last part that I
        # wanted to focus on here was this...
"""
    # The __str__ method returns the objects state
    # as a string
    def __str__(self):
        return "Name: " + self.__name + \
            "\nPhone: " + self.__phone + \
            "\nEmail: " + self.__email
"""
        # take a look at what is going on here we are using the __str__ method and what it is doing is that its going
        # to be retuning the so going back to the notes that we covered here what we are doing is that we are building 
        # this str method and all its doing is that the parameter that we are giving each variable we are then just 
        # going to be printing out the variable so its just going to call str and then print out the object and what 
        # we defined as strings simple to understand.

# %%
try:
    f = open("test_file.py")
    var = bad_var       # Did this on purpose to Highlight a point
except FileNotFoundError as e:
    print(e)
except Exception as e:
    print(e)

#____________________________________________________________________
# SUMMARY:
    # So within our try block we are going be opening the file and lets say that the file doesnt exist here so now
        # now we have the Exception where if any occurs here then it says the message that we want it to say the goal
        # of the try and except is to get the errors properly and now just general errors the more specific the better
        # so this general Exception isnt only going to find the file not found error its also going to be getting the
        # all the other problem that we run into take a look at the next line of code...
"""
    var = bad_var       # Did this on purpose to Highlight a point
"""
        # here the thing that you need to know is that we put a bad variable and now if we run the code there are two
        # errors the file not found and that the variable is bad so that is why we need to use the apporiate error
        # handling that is something important to consider when working with this try and EXCEPTION so we have to
        # specify it specificy other wise its going to print that the file is not found and that is not the only error
        # that we see here.
"""
try:
        f = open("test_file.py")
        var = bad_var       # Did this on purpose to Highlight a point
except FileNotFoundError:
    print("Sorry. This file doesnt exist")
"""
        # So here now this is going to be giving us a regular traceback error because the file was found and its there
        # but now that it sees the error its like yo bro this thing has bad variables.
"""
    try:
        f = open("test_file.py")
        var = bad_var       # Did this on purpose to Highlight a point
    except FileNotFoundError:
        print("Sorry. This file doesnt exist")
    except Exception:
        print("Sorry something went wrong")    
"""
        # So here this was a good reacap of everything but the general Exception should be on the bottom that is
        # something that you need to understand the reason why its going to start with the frist branch and then the
        # second branch and then the last branch and had you put general second then its going to start at there it
        # work similar to if elif else clause.
"""
    try:
        f = open("test_file.py")
        var = bad_var       # Did this on purpose to Highlight a point
    except FileNotFoundError as e:
        print(e)
    except Exception as e:
        print(e)
"""
        # This way what we are doing is that when we use an alias what happens is that we then print out directly what
        # error it is going to be that is something important to consider here

# %%
car = {
    "brand": "Ford",
    "model": "Mustang",
    "year": 1964
}
x = car.get("model")
print(x)

#_________________________________________________
car = {
    "brand": "Ford",
    "model": "Mustang",
    "year": 1964
}
x = car.get("price", 15000)
print(x)

#_________________________________________________________________________________________________________
# SUMMARY:
    # So we are going to be talking about the get method it returns the value of the item with the specified key
        # this was a simple method that we learned when it comes to working with dicts the thing that I wanted to
        # highlight here was that when it comes to the second part what we are doing is that notice that the price
        # function doesnt exist so we then do it this way where we have the price function set and then its going to
        # return 15000

# %%
# GENERAL NOTES:
    # File handling is an important part of any web application
    # Python has several functions for creating, reading, updating, deleting files
    # 3 different types of file modes "r" - read, "a" - append, "w" - write and the last
        # is "x" - creates the specified file the append and write create the file if it
        # doesnt exist while the rest retrun an error if the file doesnt exist

f = open("demo_file", "w")
f.write("Hello! Welcome to demofile.txt"
        "\nThis file is for testing purposes"
        "\nGood Luck!")

f = open("demo_file", "r")
print(f.read())

# By default the read method returns the whole text but you can also specify how many characters you want to return
    # the important thing to understand here is that when it comes to this code you can speicfy the arguemnt inside
    # the read() and this gives the amount of characters that the function is going to read. You should always close
    # your files in some cases due to buffering changes made to a file may not show until you close your file.

# GENERAL NOTES:
    # So here there was something that I wanted to point out in this code and that being the first thing that I had
    # noticed here was when I used another variable such as z and tried reading the file it was not wokring so when
    # I had used the same variable what had happened was that it had started working

f = open("demofile3.txt", "w")
f.write("Woops! I have deleted the content!")
f.close()

#open and read the file after the appending:
f = open("demofile3.txt", "r")
print(f.read())

# So this was something that I wanted to talk about more in detail this was the thing that I was having a hard time on
# in the oop code we are working with pickling data and to me I was wondering if you are writting new data to a file
# then how come it doesnt delete the file that was something that was of concern to me then I had learned here that
# when it comes to writting to file the "w" method will overwrite the entire file say if a file is holding data already
# and we use the w method to write over a file we then learn that then its going to delete everything once again

# %%
# This program manages contacts
import contact
import pickle

# Global constants for menu choices
LOOK_UP = 1
ADD = 2
CHANGE = 3
DELETE = 4
QUIT = 5

# Global constants for the filename
FILENAME = "contacts.txt"

# Main function
def main():
    # Load the existing contact dictionary and
    # assign it to mycontacts.
    mycontacts = load_contacts()

    # Initialize a variable for the user choice
    choice = 0

    # Process menu selections until the user
    # wants to quit the program
    while choice != QUIT:
        # Get the user mneu choice
        choice = get_menu_choice()

        # Process the choice
        if choice == LOOK_UP:
            look_up(mycontacts)
        elif choice == ADD:
            add(mycontacts)
        elif choice == CHANGE:
            change(mycontacts)
        elif choice == DELETE:
            delete(mycontacts)

    # Save the mycontacts dictionary to a file
    save_contacts(mycontacts)

def load_contacts():
    try:
        # Open the contacts.txt file.
        input_file = open(FILENAME, 'rb')

        # Unpickle the dictionary.
        contact_dct = pickle.load(input_file)

        # Close the phone_inventory.dat file.
        input_file.close()
    except IOError:
        # Could not open the file, so create
        # an empty dictionary.
        contact_dct = {}

    # Return the dictionary.
    return contact_dct

# The get_menu_choice function displays the menu
# and gets a validated choice from the user.
def get_menu_choice():
    print()
    print("Menu")
    print("_______________________________")
    print("1. Look up a contact")
    print("2. Add a new contact")
    print("3. Change an existing contact")
    print("4. Delete a contact")
    print("5. Quit the program")
    print()

    # Get the user choice.
    choice = int(input("Enter your choice: "))

    # Validate the choice.
    while choice < LOOK_UP or choice > QUIT:
        choice = int(input("Enter a valid choice: "))

    # return the user choice
    return choice

# The look_up function looks up an item in the
# specified dictionary.
def look_up(mycontacts):
    # Get a name to look up.
    name = input("Enter a name: ")

    # Look it up in the dictionary
    print(mycontacts.get(name, "that name is not found"))

# The add function adds a new entry into
# a specified dictionary.
def add(mycontacts):
    # Get the contact info
    name = input("Name: ")
    phone = input("Phone: ")
    email = input("Email: ")

    # Create a Contact object named entry.
    entry = contact.Contact(name, phone, email)

    # If the name does not exist in the dictionary,
    # add it as a key with the entry object as the
    # assoicated value.
    if name not in mycontacts:
        mycontacts[name] = entry
        print("The entry has been added")
    else:
        print("The name already exists")

# The change function changes an existing
# entry in the specified dictionary.
def change(mycontact):
    # Get a name to look up.
    name = input("Enter a name: ")

    if name in mycontact:
        # Get a new phone number.
        phone = input("Enter the new phone number: ")

        # Get a new email address.
        email = input("Enter the new email address: ")

        # Create a contact object named entry.
        entry = contact.Contact(name, phone, email)

        # Update the entry.
        mycontact[name] = entry
        print("Information updated")

    else:
        print("That name is not found")

# The delete function deletes an entry from the
# specified dictionary
def delete(mycontacts):
    # Get a name to look up.
    name = input("Enter a name: ")

    # If the name is found, delete the entry
    if name in mycontacts:
        del mycontacts[name]
        print("Entry deleted")
    else:
        print("That name is not found")

# The save_contact function pickles the specfied
# object and saves it to the contacts file.
def save_contacts(mycontacts):
    # Open the file for writting
    output_file = open(FILENAME, "wb")

    # Pickle the dictionary and save it.
    pickle.dump(mycontacts, output_file)

    # Close the file.
    output_file.close()

# Call the main function
main()
#_________________________________________________________________________________________________________________
# SUMMARY:
"""
    import contact
    import pickle
    
    # Global constants for menu choices
    LOOK_UP = 1
    ADD = 2
    CHANGE = 3
    DELETE = 4
    QUIT = 5
    
    # Global constants for the filename
    FILENAME = "contacts.txt"
"""
    # So take a look here we are importing the contact module and this is a reference to the menu option here so take a
        # look at this code this is a small recap of everything that we done but we are making a menu and then we are
        # using a file naming constants the thing that I wanted to highlight in this code is that we are going to be
        # using this outside of our main because had we used them within a function then we have to specicy the parameter
        # and then label the value that is something important to consider take a look at the next code...
"""
def main():
    # Load the existing contact dictionary and
    # assign it to mycontacts.
    mycontacts = load_contacts()

    # Initialize a variable for the user choice
    choice = 0

    # Process menu selections until the user
    # wants to quit the program
    while choice != QUIT:
        # Get the user mneu choice
        choice = get_menu_choice()

        # Process the choice
        if choice == LOOK_UP:
            look_up(mycontacts)
        elif choice == ADD:
            add(mycontacts)
        elif choice == CHANGE:
            change(mycontacts)
        elif choice == DELETE:
            delete(mycontacts)

    # Save the mycontacts dictionary to a file
    save_contacts(mycontacts)
"""
    # So lets take a look at what is going on here first and foremost we created the main function this is where the
        # main code is going to run here we created an object variable that is linked to the load_contacts() method and
        # we preset a choice to 0 and we set the while loop to while choice is not equal to QUIT and the thing to under-
        # stand here is that they did something that appeared different to me and that was that they had preset the
        # choice variable with 0 so that means that the while loop will run that is such a simple concept because I
        # remember when I made a program I was running with the same problem where I didnt know how to start the loop
        # without having to get input first and here they just put a preset variable and said if not preset variable
        # then start the loop I found that to be really interesting when it comes to this code the second part of this
        # code is this...
"""
    # Get the user mneu choice
    choice = get_menu_choice()
"""
        # take a look we created an object variable here and then we set it to the get_menu_choice() now the thing to
        # understand here is that when we created this what this is going to be doing is that it is getting a value
        # from a function and then storing it to our variable that we created that is going to be used in the while
        # loop that is really important point to consider when it comes to working with this code..
"""
    if choice == LOOK_UP:
        look_up(mycontacts)
    elif choice == ADD:
        add(mycontacts)
    elif choice == CHANGE:
        change(mycontacts)
    elif choice == DELETE:
        delete(mycontacts)
"""
        # so take a look here at what is going on we were saying that choice == LOOK_UP: then we call the look_up
        # function and something that I wanted to iterate here was that when it comes to working with the look_up
        # function what exactly is it that is important to understand here is that we are inputting something constant
        # in the function that we created and that is called mycontacts now lets go back to the code that we determined
        # and skiimed over to see what it is...
"""
    mycontacts = load_contacts()
"""
        # Take a look here now the thing that I wanted to mention was that the load_contacts is actually storing an
        # exisiting dictionary so that this will make more sense later on...
"""
    # Save the mycontacts dictionary to a file
    save_contacts(mycontacts)
"""
        # So take a look here we called the save_contacts() this is a function that saves mycontacts dict to a file the
        # thing that we need to understand is that we are using another method that is getting a dict and its going into
        # 4 different paths that are going to be doing different thing to the dict its similar to nodes and roads where
        # one road can brach out to 4 different roads that is something important to consider. and the last is the 5th
        # road which is going to be taking the data to another function to do something the if, elif, else are the main
        # branch of the code
"""
    def load_contacts():
        try:
            # Open the contacts.txt file.
            input_file = open(FILENAME, 'rb')
    
            # Unpickle the dictionary.
            contact_dct = pickle.load(input_file)
    
            # Close the phone_inventory.dat file.
            input_file.close()
        except IOError:
            # Could not open the file, so create
            # an empty dictionary.
            contact_dct = {}
    
        # Return the dictionary.
        return contact_dct
"""
        # So the very first thing to understand in this code is that we are loading an existing dict and then assigning
        # it to the mycontacts the thing to know here is that this dict is going to be going to different paths what
        # we are going to be doing in this branch the first thing that we need to know is that we are opening the
        # FILENAME and rb we created an object variable that is going to be doing that the second thing that we need to
        # know is that we are then calling the pickle.load(file stored in object variable) and this is going to be
        # opening the contacts.txt file in readbyte mode the next thing that we are going to be talking about is that
        # we are going to unpickling the dict now something that I watned to mention here was that when we first run
        # this program it has nothing stored there meaning that it has no data so then you might be wondering why is
        # thier no data and how are we going to unpickle it and the answer to that is really simple because the reason
        # why is that what we do is that we call the function that is going to add data to it and thus doing so what
        # happens is we write data to file and then it reads from the file we are going to be talking about that in more
        # detail the other thing that you need to know is that when it comes to IOError that means that when the open
        # function cant open a file so it gives this error so we said try this where we read byte from the file that we
        # want store it to a variable and then pickle.load that file and store it to an object variable and then we
        # close the file the second thing that we need to know is that when we have an IOError that means that this
        # file is not there so what we are going to do is create an empty dict and then send that off that is an
        # important point to consider here when it comes to working with this the important point to understand here is
        # that when the file is there then read from the dict and if the file is not there its going to run into an
        # IOErrror then create a new dict and send it there
"""
def get_menu_choice():
    print()
    print("Menu")
    print("_______________________________")
    print("1. Look up a contact")
    print("2. Add a new contact")
    print("3. Change an existing contact")
    print("4. Delete a contact")
    print("5. Quit the program")
    print()

    # Get the user choice.
    choice = int(input("Enter your choice: "))

    # Validate the choice.
    while choice < LOOK_UP or choice > QUIT:
        choice = int(input("Enter a valid choice: "))

    # return the user choice
    return choice
"""
    # So luckily this is something that we already covered its a simple display menu and we are getting the user choice
        # and storing it to a variable and running a simple input validation meaning that the choice has to be between
        # 1-5 and not execceding it and if it is not in that then enter a valid choice and we just return the choice
        # the thing that is smart is we are using for when something is something its soemthing that its not so when we
        # get the input from the user we then run the input validation and check to see if someone messes up and we get
        # the input again I really liked this approach here and we just return choice variable so we know the get_menu
        # _choice is going to be returning to a variable that is important to understand here but then lets look at how
        # it works back in the main once again since we pre-set choice to 0 what happens is that we then get the pre-run
        # so its going to display the menu the first time and then we get the real user choice that is returned from
        # our method and then it goes to its brackets on which branch its going to follow the mistake that I made when
        # it comes to this code was that I was thinking to myself that this is going to be display the menu and no that
        # is not the case what this is the backend meaning the decision path of where the code is going to run that is
        # something important to understand when it comes to this code so that is why we can preset it with a variable
        # and then get the input later on that is really smart to understand when it comes to this code.
"""
    def look_up(mycontacts):
    # Get a name to look up.
    name = input("Enter a name: ")

    # Look it up in the dictionary
    print(mycontacts.get(name, "that name is not found"))
_______________________________________________________________________________________    
    USING THIS PART OF CODE:

    if choice == LOOK_UP:
    look_up(mycontacts)    
"""
        # something that we need to understand when it comes to this code is that we are taking in the dict that is with
        # the function now that we know here is that whats happening is that we bringing the dict into our function
        # and then we are searching for name and then using the get function that is going to check if that name is
        # in the dict and the thing that I noticed is to use the get you have to use the dict and then its method its
        # common convention and what this is doing is that its going to find the key and if its there then it gives
        # the name and if name is not found then it prints the message something that I wanted to point out here is
        # that this code is simple its just checking to see if something is in our dict this is something that we had
        # already wrote like 10 times its cool to understand how this is working though
"""
    def add(mycontacts):
        # Get the contact info
        name = input("Name: ")
        phone = input("Phone: ")
        email = input("Email: ")
    
        # Create a Contact object named entry.
        entry = contact.Contact(name, phone, email)
    
        # If the name does not exist in the dictionary,
        # add it as a key with the entry object as the
        # assoicated value.
        if name not in mycontacts:
            mycontacts[name] = entry
            print("The entry has been added")
        else:
            print("THe name already exists")
"""
        # Take a look at the next function now we already know that we are using dict values that is important point
        # to consider here but here is what we did we got the name and then the phone and then email from the user
        # and we created an objects to add we called the module the class and then the args now the thing to know here
        # is that we have our dict and we are adding it as an object
"""
    # Create a Contact object named entry.
        entry = contact.Contact(name, phone, email)
"""
        # take a look at the next part of the code here is what we are doing here...
"""
    if name not in mycontacts:
        mycontacts[name] = entry
        print("The entry has been added")
    else:
        print("The name already exists")
"""
        # so this is where the magic is happening what we did was that we created an object variable taht is going to
        # be storing the name, phone, email and then if name not in the dict that we made what we are doing is that we
        # are adding the name as the key value and the the entry which is the object variable that is holding all the
        # other inforamtion such as the name, phone and email and that is being stored to the dict the question that I
        # had was that how is this getting stored we know that we are storing an object and then in it we are storing
        # the name phone and email the point that I wanted to highlight here was that when it comes to the keys its
        # showing the name as the key and when it comes to the values it comes to entry which is going to be the object
        # variable that is something important to consider when writting this code.
"""
    def change(mycontact):
        # Get a name to look up.
        name = input("Enter a name: ")
    
        if name in mycontact:
            # Get a new phone number.
            phone = input("Enter the new phone number: ")
    
            # Get a new email address.
            email = input("Enter the new email address: ")
    
            # Create a contact object named entry.
            entry = contact.Contact(name, phone, email)
    
            # Update the entry.
            mycontact[name] = entry
            print("Information updated")
    
        else:
            print("That name is not found")
"""
        # So lets begin with this code what is happening here is that we are getting the my_contacts variable that is
        # holding the dict we then search for a name and then we say a simple thing of if name in the dict that we
        # chose my best assumtion is that its going to be checking the keys and then we get the phone input and then
        # the email and then we create a new object that is going to hold the phone and email to that name so this is
        # all new its showing us that when it comes to working with obejcts and dict you can even use one parameter
        # value that was something that we did in the last code and once we do that we then set the key as the name
        # and when it comes to the value we set it as the entry and if name not in my contacts then its going to say
        # that the name is not found something new in this code was that we can change the objects parameter value and
        # also search up the value as well.
"""
    def delete(mycontacts):
        # Get a name to look up.
        name = input("Enter a name: ")
    
        # If the name is found, delete the entry
        if name in mycontacts:
            del mycontacts[name]
            print("Entry deleted")
        else:
            print("That name is not found")

"""
        # now the delete function is really simialr one thing that I wanted to mention was that these functions are
        # literally the methods so you just need to know how to use them now what we do is that we get the name from
        # the user and then we check if the name is in mycontacts which is the dict that we made and when it comes to
        # delete the name key what we are going to do is call the del dict[key] and we already know that this is going
        # to delete the key and then it prints that the entry has been deleted and if name is not in dict then its
        # gong to print name is not found
"""
    # The save_contact function pickles the specfied
    # object and saves it to the contacts file.
    def save_contacts(mycontacts):
        # Open the file for writting
        output_file = open(FILENAME, "wb")
    
        # Pickle the dictionary and save it.
        pickle.dump(mycontacts, output_file)
    
        # Close the file.
        output_file.close()
"""
        # Take a look here this code is a reference in the main block...
"""
    # Save the mycontacts dictionary to a file
    save_contacts(mycontacts)
"""
        # here we learned that this save the dict to a file so this is what this code is going to be doing one that
        # suprised me is how it is at the end so lets start off by what it is doing its writting dict to the file that
        # we created and that was contacts.txt and it is stored as wb and we are using the pickle the dump and then the
        # name of the dict and the filw that we want to write to the question that I had on my mind was that when it
        # comes to adding new stuff and each time we run the program how come it doesnt disappear or something that is
        # an important point to consider when writting this program another thing is when you use open be sure to use
        # the close.
#________________________________________________________________________________________________________________
# SUMMARY:
    # So this is a recap from the notes in the reading there are new thing that I learned from there and its going to
        # be talking about all the details that we covered and then the notes from the book. SO we learned about the
        # pickle object and we know that it is seralizes objects serailizing object means converting it to a stream of
        # bytes that can be saved to file for later retrieval the pickle module dump function serializes an object and
        # writes it to a file and the load function retrives an object from a file and deserializes it or unpickles it
        # dict objects can be pickled and also you can pickle or unpickle objects of your own classes. dictionaries are
        # also useful for storing objects that you create from your own classes the book then goes onto mention
        # something important that I really liked "each time the program creates a Contact object holding a specific
        # person data that object would be stored as a value in the dict using the person name as the key then when you
        # need to retrieve a specific person data you would use that person name as a key to retrieve the Contact obj
        # from the dictionary" this was vital information because this was something that I was noticing that we were
        # storing an object but we were using the key as the name which was in the object and I was wondering to myself
        # that how come we can call the name here it doesnt make sense? this is another part of the note that you
        # should know but "the program automatically pickles the dict and saves it to a file when the user quits the
        # program when the program starts it automatically retrives and unpickles the dict from the file that is
        # something that we learned in chapter 10 where pickling something saves it to a file and unpickling something
        # then retireves it from a file if the file doesnt exist that is why the program starts with an empty dict
        # something that I wanted to highlight here was that when it comes to this is that when we are writting to a
        # file that is why the data is not being erased because when data is stored to a file then its going to be
        # stored there I think when it comes to writting with files that is why when we write more data to the file the
        # previous data is not being taken away the thing that was coming to my mind was that when it comes to writting
        # to files the thing that I learned was that each time we re-run the file data gets erased but this is working
        # with pickle files we are dumping objects to the file and they are being saved and then all we are doing is
        # then loading it. "Inside the main function line 19 calls the load_contact function keep in mind that if the
        # program has been run before and names were added to the dict those names have been saved to the contacts.dat
        # file " this is what the code is referring to here meaning that we are saving to a file that is why the
        # previous names are not disappearing the important thing to understand is that when we are reading from a file
        # the important point to understand is that if the file doesnt exist then what are we going to do here so
        # that is why it is important to return a reference or empty dict each time you open a file. "When the user
        # selects item 5 from the menu the while loop stops repeating the statement calls the save_contacts function
        # passing mycontacts as an argument the save_contacts function saves the mycontacts dict to the contacts.dat
        # file. the last function the important thing to realize here is taht once we exit the loop whats going to
        # happen is that we are going to get the dict and then write it to a file now this was something that I had
        # thought was going to be interesing here because what happens is that this most likley is going to be working
        # with the add where each time we are adding a obj the thing that we need to be aware of here is that some
        # notes that we already covered "inside the try suite we open the contacts.dat file if the file is opened it
        # loads the dict object from it unpickles it and assigns it to the contact_dct variable if the file doesnt exist
        # this will be the case if its the first time the program is run the statement leads and IOError exception now
        # this was something that I had skimmed over but it makes sense I didnt think about how we have to think the
        # first time the program runs so it makes sense that when it comes to the program running the first time the
        # file doesnt exist then we return an empty dict and that is going to the save_contacts method and that is
        # writting the data to the file that is something that you need to know it makes sense. My theory is that when
        # it comes to this when you are creating the file for the first time what happens is that you run into an
        # IOError and then you have to handle the error by creating an empty dict and then its going to write the empty
        # dict to the file that is an important point to consider. The next thing that we are going to be talking about
        # in more detail is the get method earlier we talked about how the methods can be used but there was something
        # new in this that made more sense so we know that the get method is going to be searching the key value and
        # when we look at this code its going to be searching for the name and now this gives us a clue that when it
        # comes to the name that is going to be stored as the key the real storage is happening in the add method and
        # another thing is that when it comes to these method it really doesnt matter which order it matters which order
        # that you are going to be calling the method in. "If the specified name is found as a key in the dict the get
        # method returns a reference to the Contact object that is assoicated with the name The contact object is then
        # passed as an argument to the print function the print function displays the string that is returned from the
        # Contact object __str__ method" the thing that I found to be suprising here is that we are when it comes to
        # its going to print the name, phone and email what I found to be interesting here is that how does this code
        # know to print those three things as suppose of printing only the name value and how does it tie up to the
        # __str__ first and foremost its most important to understand when it comes to the get method for dict is
        # different for the get like getters that is the first thing so this goes back to our notes on when it comes
        # to the __str__ method and its called string represenation each time we create an object and then print the
        # object then we can insert the self statements so when we are saying get the name my best bet is this that
        # its going to be going to the self.name and since this is activated its going to print the name, phone, email
        # that is an important point to consider when writting this code this is what the notes is saying and it makes
        # sense when it comes to this code the real thing to understand is this we know that the dict is going to be
        # storing the name as the key and then the obj identiy as the value and when we call the get name then its going
        # to be printing the name, phone, email and they are attributed to the self.__name and all the stuff that has
        # to do with self and then it goes to the __str__ and it prints out all the self that is an important point to
        # consider when it comes to working with this code So now we are going to be talking about the add function and
        # hopefully this is going to clear out everything here we are getting the name, phone, email from the user and
        # then we already know that we create an object then we save the object as the value and the name as the key
        # the reason why I wanted to highlight this here was that this is the entry step the question the purpose of the
        # add function is to allow the user to add a new contact to the dict it accepts the mycontact dict as an arg
        # something that I learned with this code was that when I write an entry it seems to stay there even when I
        # rerun the program so there is a lot that is going on first we have to understand that we are creating an
        # entry object and we then cross reference to see if name not in contacts which is the dict that we made the
        # thing that I wanted to highlight here was that name is the same as the thing that is going into our input
        # there really is just one part of the code that I am trying to figure out how is the information staying in
        # the file? I think I was able to figure it out the best way to think of this is as a river that spreads into
        # 4 channles and at each channel you can do wahtever you want to it that is the important thing to understand
        # so when it comes to this code in the beginning what is going to happen is that we load the contact and then
        # we pass the contact dict to each different channels the mistake taht I made was in thinking that the add
        # funcition begins first so the add is more so of the follow up meaning like if we need to add names to our dict
        # and the init is in load contact we either load up the contact or an empty dict if file is not there and if
        # the file already exist then whats going to happen is that file object is just going to get loaded up

# %%
class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def get_name(self):
        return self.name

    def get_age(self):
        return self.age

    def set_age(self, age):
        self.age = age

    # def add_one(self, x):
    #     return x + 1
    #
    # def bark(self):
    #     print("bark")

d = Dog("Tim", 10)
print(d.get_name())
d.set_age(20)
print(d.get_age())

# print(d.name)

# d2 = Dog("Bill", 12)
# print(d2.get_name())
# print(d2.get_age())

# print(d2.name)

# print(Dog.add_one("Tim", 1))
# a = Dog.bark("Tim")

#_________________________________________________________________________________________________________
# SUMMARY:
    # So here there is something that you need to know the first thing that we learned was that the difference between
        # an attribute vs parameter and how we need to use parameter to activate our instance the second thing that we
        # need to cover here is that notice how we are saying print name I was wondering is this reffering to the
        # attributre or the parameter and it was referring to the parameter that was something that I was getting
        # confused on the second thing that I found to be new was how we were calling print name in our init this was
        # new because I was used to having to set up the attributes so that the code can be initialized and be used
        # later on for the objects that we create now this code is pretty simple not going to lie what we are doing is
        # that we are creating two objects and then passing in the name using the class and then since the print is in
        # the init its going to be printing the name that is the first thing that you need to know the thing that had
        # suprised me in the next part was this...
"""
    print(Dog.add_one("Tim", 1))
"""
        # look at what we are doing here is that we are creating a class and then calling the method and then here I
        # thought that since its only taking in one arg that means that we need to fill in with a name that is what I
        # was thinking instead what had happened was that we passed in the arg Tim and then we passed in 1 and then we
        # called the print that is when it printed out 2 I was suprsied by this the second thing that we did was that
        # we had passed in a name to the bark method instead of it just running from the getgo
"""
    a = Dog.bark("Tim")
"""
        # that was something that I found out to be really new when it comes to working with this code that we have to
        # pass in an arg even tho we have only one parameter value
"""
    d = Dog("Tim")
    print(d.name)
"""
        # this is over concepts that we already covered here and that being we are creating an object called d and then
        # init it with Tim and then using that object to call onto the attribute that is something that I wanted to
        # highlight was that I was getting confused wheter it was calling the parameter or the attribute once again and
        # it was calling the parameter that is something important to consider when working with this code.
"""
    class Dog:
    def __init__(self, name):
        self.name = name

    def get_name(self):
        return self.name

    d = Dog("Tim")
    print(d.get_name())
"""
        # So here the thing that I wanted to ellaborate here on was that notice what we are doing was that we have set
        # the parameter as name and an attribute set as self.name its important to make the distinction that self.name
        # is different from name the next thing that we did was that we created a function called get_name and this
        # is going to return the attribute that we made the important thing to understand is that why did we use the
        # parameter here? instead when we are returning the self.name in the second method and its really simple its
        # because we are trying to get a value that we can put in for our attribute that makes it different from the
        # second funtion the best way to think of this is that these are two different code one is more so of the init
        # value that is going to be initalzing and the other method is going to be returning the initalizing value its
        # important not to get it confused thinking that the attribute and the parameter are the same thing so notice in
        # the next part what we did we created an object variable and them passed in an argument and then we used that
        # object and called the method buts important to understand why this method we didnt really pass anything in
        # and that is because we passed into to class so therefore the method just returned this was confusing me
        # because I was wondering to myself that how come for this method that we created we are not putting in any
        # parameter value when we are just returning the attribute value
"""
    # print(d.get_name())
    # print(d.name)
"""
        # So take a look here this was something that I wanted to highlight here was that this code even though is
        # doing the same thing they are two different process the first is a method and the second is calling a
        # parameter that is an important point to consider when writting codes like this.
"""
    class Dog:
        def __init__(self, name, age):
            self.name = name
            self.age = age
    
        def get_name(self):
            return self.name
    
        def get_age(self):
            return self.age
    
    
    d = Dog("Tim", 10)
    print(d.get_name())
    print(d.get_age())
"""
        # So take a look at what is going on here now what we did was that we created a Dog class and then we passed
        # in name and age we then created a function called get_name and then get_age and they are simple functions
        # that are doing things that we already discussed here now the thing that I wanted to ellbaorte on here was
        # that say if you didnt pass in the self for get_age you would run into an error and it will say postional
        # value error that its been given 0 when there is one and now you might wonder wait a minute we are get_age
        # doesnt have an parameter that we have been given then why is it saying that its been given one and the
        # answer to that is really simple we are just passing in the self that passes in invisible we already discussed
        # here how it works and it passes to each method so that is why its important to understand that concept that
        # when we are passing in the self its the "invsible parameter"
"""
    class Dog:
        def __init__(self, name, age):
            self.name = name
            self.age = age
    
        def get_name(self):
            return self.name
    
        def get_age(self):
            return self.age
    
        def set_age(self, age):
            self.age = age
    
    
    d = Dog("Tim", 10)
    print(d.get_name())
    d.set_age(20)
    print(d.get_age())
"""
        # So lets take a look at what is going on here the first thing that we need to know is taht we are making a
        # setter here and that is called set_age and we are taking in a parameter value we then use this setter to
        # override with a value and then go call another method that is going to return the self.age now the thing
        # that I wanted to highlight here was that we are going to be covering what makes setters different from getters
        # and this is something that we understand the concept but to truly understand what it is talking about seems
        # really cool so the first mistake that I had made when it came to writting this code was that for the set_age
        # what I did was that I didnt do this step
""" 
    self.age = age
"""
        # now this was something that I wanted to ellborate on here this is whats known as a change attribute that is
        # something important to understand I knew what this was doing but I didnt really understand why this is what
        # I wanted to demonstrate was that the getters are returning the attribute and the setters are basically
        # changing the attribute the important thing to understand is that we are using the change flip that is
        # something important to consider when it comes to working with this code why we take in a parameter
        # and then over-ride our attribute and that is why we dont pass anything into our getters because all we are
        # doing is that we are just returning our attribute becasue we dont need to change it we just need it to be
        # displayed
"""
    d = Dog("Tim", 10)
    print(d.get_name())
    d.set_age(20)
    print(d.get_age())
"""
        # So take a look here the thing that I wanted to highlight here is that there is two things happening here
        # the first is that I kept getting confused that do I call the class and then method or do I create an obj
        # variable and the answer to that is really simple when we first create our obj we need to use the class
        # because we are going to be init it with the arguments that we are going to pass into the parameters to get
        # our attributes and then when we need to use each method we can then use the obj variable and then use the
        # method that we created the thing that I wanted to mention here is that there are two breathing technique here
        # one being that we create the obj and then use the class to fill in args and then we use that variable that
        # is obj and then call the methods those are two important distinction to understand when it comes to making
        # this
    # So now the question is why do we use oop programming and the answer to that is really simple to understand that
        # being we create many objects so instead of doing it this way what if we created variables and simply set them
        # as names and then age or something but that would be time consuming what we do is we create an obj variable
        # and then pass in the arg to their respected parameters and then we created 10 different critera as suppose of
        # creating it 10 different times that is important thing to understand when it comes to this code we can do it
        # where we create list or something now the drawback to that plan is say we want to remove something then what
        # is going to happen we have to remove that index from other list and it can get really condusing really fast
        # that is why we use object oriented programming because it gives more order as suppose of just doing it linear

# %%
class Student:
    def __init__(self, name, age, grade):
        self.name = name
        self.age = age
        self.grade = grade

    def get_grade(self):
        return self.grade

class Course:
    def __init__(self, name, max_student):
        self.name = name
        self.max_student = max_student
        self.students = []

    def add_student(self, student):
        if len(self.students) < self.max_student:
            self.students.append(student)
            return True
        return False

    def get_average_grade(self):
        value = 0
        for student in self.students:
            value += student.get_grade()

        return value / len(self.students)

s1 = Student("Tim", 19, 95)
s2 = Student("Bill", 19, 75)
s3 = Student("Jill", 19, 65)

course = Course("Science", 2)
course.add_student(s1)
course.add_student(s2)

#print(course.students[0].name)
print(course.add_student(s3))
print(course.get_average_grade())

#_________________________________________________________________________________________________________
# SUMMARY:
    # So this code thus far is teaching us new concepts the first thing that I wanted to mention was that was going
        # on here is that we created a Student class and here we gotten 3 different parameter which set up our
        # attributes values we got the name age and then the grade the next thing that we did was that we did get_grade
        # function and all it was doing was that it was returning the self.grade the next class that we made was the
        # class called Course and here its going to be taking in two different parameters the name and max student
        # here we set the name of the course and the max student the one thing that I wanted to highlight here was that
"""
    self.students = []
"""
        # this is something that you want to focus on here that we have an attribute called self.students = [] and then
        # an empty list is being passed here the thing that makes it different from the other thing that we leanred was
        # that usually we set up a parameter and then it sets up an attribute but in this case notice that it is not
        # doing that instead what it is doing is that its independent and stands on its own so the next thing that we
        # are going to do is that we created a new method called add_student and that was taking in a parameter value
        # now in the new parameter we are using some of the attributes that we set above for example we are saying that
        # if len of the list that we created in the init clause is less then the max student then the list.append the
        # parameter and then return True else return False now there is a lot to understand there but its really simple
        # to understand the thing that I wanted to highlight here is that notice how we are using the list which is in
        # the other init and now you might be wondering well how is that posssible?
"""
    def add_student(self, student):
        if len(self.students) < self.max_student:
            self.students.append(student)
            return True
        return False
"""
        # its all because of the self the thing that I find brillant about this code is that we are getting input from
        # the user as to see how much max students we want and then we are saying in our condition if the list of
        # student len is less then the max student notice how the list is an empty value that we created and its what
        # I called an unlinked attribute notice how max_student is a linked attribute we then do list.append(student)
        # now here is what you are probably thinking what is student? where is this coming from and where is this
        # referring to? that is important to consider now this code is about conept more then anything we need to
        # understand how is this code factoring into everything ? like how is it working together with the other class
        # that we created if you can grasp that point then it becomes clear so the point that I wanted to iterate here
        # was that when it comes to this code what you can do is that you can craete a attribute to hold a data type
        # and then use other attributes together that are in the class to set up a conditional statement and just as
        # you are setting it up the thing that you need to know is that you can also use parameter values within the
        # method the thing that I wanted to highlight here is that we are using not only attributes rather we are using
        # parameter values how you might ask is that we use the attributes in another method that is key detail point
        # that you need to understand
"""
    s1 = Student("Tim", 19, 95)
    s2 = Student("Bill", 19, 75)
    s3 = Student("Jill", 19, 65)
    
    course = Course("Science", 2)
    course.add_student(s1)
    course.add_student(s2)
    print(course.students[0].name)
"""
        # So lets take a look here what is going on here the first thing is that we are creating 3 different objects in
        # which we have the name the age and the grade and that is going to be passed in to the Student class and its
        # important to understand that when it comes to the student class we have the get_grade() method that is going
        # be used for that class so if you need to call it then you have to use that instance of the class the second
        # thing that you need to konw is that what we are doing is that we are creating an object variable that is going
        # to be storing the arg / parameter value for the course class that is another important point to understand
        # because this had suprised me here where I was like wait a minute how come we are adding two arg here and not
        # 3 the important thing to understand is that for each class we take in its set of arguments that is an
        # important point to understand when it comes to this code now here is where the cool part shows up what we are
        # ding is that we are using the object variable and then using the method that we made and then adding the
        # other object that we stored here...
"""
    course.add_student(s1)
"""
        # so what I wanted to expand on here was that we are using the class that we created then the method for that
        # class and then the objects that we created we add to that list because the method add_student is going to be
        # taking in a student value so in actuallalty this line...
"""
    def add_student(self, student):
"""
        # this is the function that we created and this student that we wrote is going to be taking the object variable
        # of the other class and then adding it to the list that is in our class now the thing that I wanted to
        # highlight here is that I find it cool how this code is teaching us that we can use other methods within a
        # class that are going to be taking in object variables that we create so now the list is basically saying that
        # if len of the list is greater then max student the other thing that I wanted you to focus on here is that
        # when it comes to the Course class the question that is on your mind is that why did we have to specify how
        # many people are going to be in the Course class and the answear to that is really simple beacause that is
        # going to be the size of our list...
"""
    print(course.students[0].name)
"""
        # Take a look here at what is going on we are calling the obj variable that we created and then we call the
        # student list and then the index 0 which is going to be the first element in the list and then call its name
        # the thing that I wanted to highlight here is that the mistake that I made was that I was thinking that self.
        # name is going to be in the other class when in reality it was not it was actually in the the Course class
        # and this goes to show how we can use attributes that are in our class that is an important point to consider
        # now the final question is why this format? we know we need the obj variable to get access to the methods and
        # we know we have to call the list now something that you need to know is that when we call an attribute we
        # with the obj variable we dont need to call the self that was something that I was wondering where I was like
        # wait how come we are not calling the self and just calling the attribute variable directly another thing that
        # you need to know is that when it comes to attribute and parameter the mistake that I can see myself doing is
        # that adding a parameter value to an attribute that I really dont need to and to think that when I call that
        # attribute it needs to have a parameter value lined up then and you need to use self that is not the case and
        # that is something that you need to know
"""
    def get_average_grade(self):
        value = 0
        for student in self.students:
            value += student.get_grade()
    
        return value / len(self.students)
"""
        # so lets take a look here at what is going on so there is a lot so I wanted to do a quick recap of everything
        # that we have done we are going to create Student class objects using the Student class something that new
        # that we are learning is how to use methods on elements wihtin our list that seemed kind of new to me so first
        # we need to know that the get_grade() function is going to be returning self.grade() the second thing that we
        # need to know the second thing that we need to know is that we are going to be creating a class Course which
        # is going take the course and the max students and here we are adding objects from other class to this class
        # now the next thing that we are going to be talking about is get_average_grade this is the function you see
        # above and overall it starts of simple where we set an accumlator and then we set a for loop now take a look
        # at this line...
"""
    for student in self.students:
    
    what this means is this >>>
    
    for index in self.student_list:
        value += index.get_grade()
"""
        # take a look here this is something that I wanted to highlight here I know that we have been using student
        # really interchangbly but what this really means is this...
"""
    for index in self.student_list:
        value += index.get_grade()
"""
        # So this is what this is saying the thing that I wnated to highlight here is that when it comes to this we
        # are using the index and then the list the interesting part of this code is that we are using a method that is
        # in another class now hoenstly that is new to me where I was like wait a minute we can use a function that is
        # in another class and the crazy part is that we dont define like which class it is we just use the function
        # as it is  when it comes to displaying or using the methods we have to define the class that it is in and then
        # we have to define how the function works so the real thing that you need to think of is that what is going
        # on here like? what is the logic that is behind this and that is saying for index.get_grade this means that
        # in order to solve this we need to think backwards we know that our list is holding data attributes in object
        # from so the list can look like this maybe [s1, s2, s3] and we know that each obj is holding 3 different
        # attributes so therefore s1 = self.name, self.age, self.grade once we understand what is going on here we then
        # can understand that when we are calling each object we are saying...
"""
    [s1, s2, s3]

    for index in self.student_list:
        value += index.get_grade()
                 s1.get_name()
"""
        # Now this makes more sense that when we loop thru each object within our list we can then use a methof that is
        # going to run on each obj and we know that...
"""
    def get_grade(self):
        return self.grade
"""
        # Now here we know that when we are calling the function we are getting return self.grade that is something
        # I wanted to highlight because I was wondering wait how does this work so when we call the method on the
        # object we are just getting the attribute value that to me was really cool so essetinally what you need to
        # know is that the same way we can run obj.methods we can do it this way where we store objects to list and
        # then run the method on object to get the attribute value the most important part of this code is that we are
        # trying to access the attributes here that is something that you need to know when it comes to working with
        # this code
"""
    return value / len(self.students)
"""
        # So this is the last part of the code that I wanted to talk about here and taht was here we are returning
        # the value which is our accumulator value and dividing by the len of the list just to get the average and
        # it makes sense not going to lie just the only thing that you need to know here is that notice how we are
        # using return here to divide everything.
"""
    print(course.add_student(s3))
    print(course.get_average_grade())
    __________________________________
    False
    85.0
"""
        # So here take a look at what is going on now earlier we defined how the list can not execeed more then the 
        # amount that we state of the class room so here what we are going to be doing is getting the average and 
        # instead what we are going to do is add another student now we stated in the class that the number of students 
        # like max number cannot exceed more then 2 so now we are adding another its going to return False and then 
        # its going to add the results of s1 and s2 whats crazy is that this code teaches us how to use objects add 
        # them to class and then it even does the whole checking to make sure that we are not exceeding the max amount 
        # that we stated

# %%
class Car:
    def __init__(self, make, model, year):
        self.__make = make
        self.__model = model
        self.__year = year

    def set_make(self, make):
        self.__make = make

    def set_model(self, model):
        self.__model = model

    def set_year(self, year):
        self.__year = year

    def get_make(self):
        return self.__make

    def get_model(self):
        return self.__model

    def get_year(self):
        return self.__year

#___________________________________________________________________________________________________
# SUMMARY:
    # So first thing that we are going to be doing a review over is the UML diagram which stands for unified modeling
        # language which provides a set of standards for graphically depicting object oriented systems this is a box
        # that is divided into three sections the top being the class name middle being data attributes and the last
        # being the methods something that we need to know when it comes to the UML diagram for the Coin class and the
        # CellPhone class doesnt show the self because this is something that is reoccuring here and required. So there
        # is a techqniue when it comes to finding the classes in a given problem first we - get written description of
        # the problem domain, - identify all the nouns including pronouns and noun phrases in the description, - refine
        # the list to include only the classes that are relvant to the problem.
    # So here I am going to be stating the obivous here and that is going to the first thing that I messed up in was
        # that I was thinking that we are going to be using the () when it comes to working with the class here so what
        # we need to know is that the methods and the init are going to have the () while the class represents the class
        # itself that is something important to consider when writting this code the second thing that I was wondering
        # was that why do we do all this? and the answer is really simple lets take a look at the init value here we
        # are going to be putthing three variables in the make, model, year after that what we do is we then make
        # priavate variable and then set it to the __init__ variable

# %%
# Constants for the sales tax rate
TAX_RATE = 0.05

# ServiceQuote class
class ServiceQuote:
    def __init__(self, pcharge, lcharge):
        self.__parts_charges = pcharge
        self.__labor_charges = lcharge

    def set_parts_charges(self, pcharge):
        self.__parts_charges = pcharge

    def set_labor_charges(self, lcharge):
        self.__labor_charges = lcharge

    def get_parts_charges(self):
        return self.__parts_charges

    def get_labor_charges(self):
        return self.__labor_charges

    def get_sales_tax(self):
        return self.__parts_charges + self.__labor_charges + (self.__parts_charges * TAX_RATE)

#_______________________________________________________________________________________________________-
# SUMMARY:
    # So here we its really simple what we are doing is that we are getting two parameter values so that we can input 
        # from the object notice how our data attributes are private that is something important to understand whne it 
        # comes to working with this code the second thing that we are doing is that we are using the setters where we 
        # are getting the parameter value and then modifying our private data attribute and the getters we are just 
        # returning the private attribute we would have to print the object here to display the result the one thing 
        # that I wanted to mention on this code was taht notice how we are in the get_sales_tax we are gettiing the 
        # parameters from the self and then adding them togehter and doing math on it the best way to think of this is 
        # that we are doing regular variable stuff the only thing that we are incorporating now is using the self that 
        # is really all there is to this code.

# %%
# Customer Class
class Customer:
    def __init__(self, name, address, phone):
        self.__name = name
        self.__address = address
        self.__phone = phone

    def set_name(self, name):
        self.__name = name

    def set_address(self, address):
        self.__address = address

    def set_phone(self, phone):
        self.__phone = phone

    def get_name(self):
        return self.__name

    def get_address(self):
        return self.__address

    def get_phone(self):
        return self.__phoned

# %%
class Car:
    def __init__(self, name_of_car):
        self.name_of_car = name_of_car

    def go(self):
        print(self.name_of_car, "Go")

my_car = Car("Toyota Camry")
my_car.go()

class Book:
    def __init__(self, title, author, publisher):
        self.title = title
        self.author = author
        self.publisher = publisher

    def get_title(self):
        return self.title

    def get_author(self):
        return self.author

    def get_publisher(self):
        return self.publisher

    def set_title(self, title):
        self.title = title

    def set_author(self, author):
        self.author = author

    def set_publisher(self, publisher):
        self.publisher = publisher

    def __str__(self):
        return "Title:\t" + self.title + "\n" \
            "Author:\t" + self.author + "\n"\
            "Publisher:\t" + self.publisher

book_obj = Book("Green Eggs and Ham", "Dr. Suess", "Your Mother")
print(book_obj.get_title())
print(book_obj.get_author())
print(book_obj.get_publisher())
print(book_obj)

#__________________________________________________________________________________________________________
# SUMMARY:
    # So here lets take a look at what is going on the first thing that we had to do was that we had to create a class 
        # Car and then we defined the __init__ where we got the name of the car when we created the object the next 
        # thing that we had to do was create a function called go and what this was going to do was that it just print 
        # the name of the car and then the string Go really simple the thing that I reviewed on here is that we had 
        # passed an parameter to the attruibute and then stored it to the object and then we used that obj to call the 
        # method it was a really simple program to understand the argument that we passed to parameter had referenced 
        # the self.name and then when we called go it then printed that name that was stored to the attribute and then 
        # the string 
    # The second thing that we did was that we created a Book class and here got the title author publisher and set the 
        # attribute with the parameter here we made the setters and getters we learned how getters just return the value
        # and settters change the value something that I wanted to ellaborate on here was the use of the __str__ the 
        # thing to know is that __str__ begins like __init__ right after def because it is a function by itself the 
        # other thing was that we dont need to pass in any arg to set up the attributes when it comes to working with 
        # the __str__ all we did was that we set up strings with the attributes that we set in the __init__ the 
        # attributes and displayed a message the next thing that we did was that we created a book_obj and here we
        # passed the parameter and then we used the get method here now the thing that I had learned here was that when 
        # it comes to the str value I was like wait a minute how come it is not printing the str and we learned early 
        # that the reason why it doesnt print the str when it comes to using the method is that those methods are doing 
        # the things that they have been programmed to do when we print the object what we are doing is that printing 
        # the self attributes that is important thing to understand when it comes to working with this code when you 
        # print the attribute then you print the strings that come attached to it after printing the object that is an 
        # important point to consider.

# %%
class SavingAccount:
    def __init__(self, inital_amount):
        self.__inital_amount = inital_amount

    def deposit_savings_account(self, deposit):
        INTEREST_RATE = 0.035
        interest_amount = (self.__inital_amount + deposit) * INTEREST_RATE
        self.__inital_amount += interest_amount

    def withdraw_savings_account(self, deposit):
        INTEREST_RATE = 0.035
        interest_amount = (self.__inital_amount - deposit) * INTEREST_RATE
        self.__inital_amount -= interest_amount

    def __str__(self):
        return "Saving Account: $" + format(self.__inital_amount, ",.2f")

class CheckingAccount:
    def __init__(self, inital_amount):
        self.__inital_amount = inital_amount

    def deposit_checking_account(self, deposit):
        INTEREST_RATE = 0.030
        interest_amount = (self.__inital_amount + deposit) * INTEREST_RATE
        self.__inital_amount += interest_amount

    def withdraw_checking_account(self, deposit):
        INTEREST_RATE = 0.035
        interest_amount = (self.__inital_amount - deposit) * INTEREST_RATE
        self.__inital_amount -= interest_amount

    def __str__(self):
        return "Checking Account: $" + format(self.__inital_amount, ",.2f")

class MoneyMarketAccount:
    def __init__(self, inital_amount):
        self.__inital_amount = inital_amount

    def deposit_money_market_account(self, deposit):
        INTEREST_RATE = 0.025
        interest_amount = (self.__inital_amount - deposit) * INTEREST_RATE
        self.__inital_amount += interest_amount

    def withdraw_money_market_account(self, deposit):
        INTEREST_RATE = 0.025
        interest_amount = (self.__inital_amount - deposit) * INTEREST_RATE
        self.__inital_amount -= interest_amount

    def __str__(self):
        return "Money Market Account: $" + format(self.__inital_amount, ",.2f")

#___________________________________________________________________________________________________________
# SUMMARY:
    # So here lets talk about what is going on the bank offers the following types of account savings, checking and
        # then money market account customers are allowed to depoist money into the accounts increasing its balance
        # withdraw money from the account thereby decreasing its balance and earn interest on the account each account
        # has its own interest rate. So essentially we have to design this using object oriented programming now this 
        # code is similar to each other but here is what is happening we are creating 3 different classes each is going 
        # to represent the bank account for example SavingAccount, CheckingAccount, MoneyMarketAccount in which we need 
        # to depoist money and then withdraw money and also display what is the object state that is also important to 
        # consider when it comes to working with this the first thing that I wanted to mention here was that we are in 
        # each class init we are getting the inital value from the user this is something that is important because 
        # this is how each account is going to be setup we also have to consider if the user were to deposit different 
        # amount in each account but overall the methods are simple lets start off with deposit savings account here 
        # what we are doing is that we are getting the interest rate of the account and then we are calculating the 
        # total interest and since it is deposit what we are doing is that we are adding it to our self attribute in 
        # this case the thing that we initalized our object with the only thing that I wanted to mention here is that 
        # the mistake that I made in this code was that I was using return what this was doing was that each time I 
        # had printed out the object it was only printing how much was stored because of the init and not how much was 
        # stored because of the method that was doing the math in this case the deposit method so my theory is this 
        # that when using return what was happening was that it was portraying the first thing in this case the init 
        # we learned once that return is used nothing else happens afterwards so that is the thing that might happen 
        # another thing to consider when writting this code was that when it comes to using the self and modifying 
        # you have to change the value of self meaning that you cant say self.x - x and expect it to change instead 
        # you have to use selfx += 1 this is actually changing the value of self and to me I was like wow that makes 
        # sense here its something that basic that we learned here but it made sense. The next thing that I wanted to 
        # talk about here is that when it comes to withdraw its doing the same thing where its doing all the math 
        # but inverse and with a different interest rate that is an important point to consider when it comes to 
        # working with this the last thing that we are talking about is the __str__ here all this is going to be print 
        # that state of the object when I didnt use a format specifer what had happened was that it was giving me an 
        # error saying that you can use int with str and when I did use a format specifer it ran the code this was 
        # something that I was very observant on the last thing that I wanted to mention here was that we are using 3 
        # different accounts savings account, checking account, moneymarketaccount that is an important point to 
        # consider as well first I was going to put them all together or do something with them together but then I had 
        # learned that it was becoming to confusing so I was like why not separate them in different classes that way 
        # it becomes more easier to manage that is something else that you need to consider.

# %%
import oop_bank_account

# Get the inital deposit to load up each BankAccount to.
inital_deposit_savings = int(input("How much initial deposit would you like to start off in your Savings? "))
inital_deposit_checking = int(input("How much initial deposit would you like to start off in your Checking? "))
inital_deposit_money_market = int(input("How much initial deposit would you like to start off in your "
                                        "Money Market Account? "))

# Define how much money that we want added to our accounts.
savings_deposit_amount = int(input("How much would you like to add to Savings? "))
checking_deposit_amount = int(input("How much would you like to add to Checking? "))
money_market_deposit_amount = int(input("How much would you like to add to Money Market? "))

# Define how much money is removed from our account.
savings_withdraw_amount = int(input("How much money would you like to remove from Savings? "))
checking_withdraw_amount = int(input("How much money would you like to remove from Checking? "))
money_market_withdraw_amount = int(input("How much money would you like to remove from Money Market? "))

# Set the inital value of the three bank accounts.
savings_account_obj = oop_bank_account.SavingAccount(inital_deposit_savings)
checking_account_obj = oop_bank_account.CheckingAccount(inital_deposit_checking)
money_market_account = oop_bank_account.MoneyMarketAccount(inital_deposit_money_market)

# Add money to our Savings Account.
print("\nSavings Account:")
savings_account_obj.deposit_savings_account(savings_deposit_amount)

# Remove money from our Savings Account.
savings_account_obj.withdraw_savings_account(savings_withdraw_amount)

# Display how much money is in the Savings Account post interest.
print(savings_account_obj)

# Add money to our Checking Account.
print("\nChecking Account:")
checking_account_obj.deposit_checking_account(checking_deposit_amount)

# Remove money from our Checking Account.
checking_account_obj.withdraw_checking_account(checking_withdraw_amount)

# Display how much money is in the Checking Account post interest.
print(checking_account_obj)

# Add money to our Money Market Account.
print("\nMoney Market Account:")
money_market_account.deposit_money_market_account(money_market_deposit_amount)

# Remove money from our Money Market Acccount.
money_market_account.withdraw_money_market_account(money_market_withdraw_amount)

# Display how much money is in the Money Market Account post interest.
print(money_market_account)

#____________________________________________________________________________________________________________
# SUMMARY:
    # So here this is really simple the only thing that I wanted to mention here and ellborate on was that when it 
        # comes to this we need different inputs for each different class different inital input and different 
        # deposit and different withdraws that way we can keep a track of where the money is going to this was something
        # that I hadnt thought of and when I did I was running into all of it being removed and added to the same thing
        # and it was getting really confusing where I was like wait a minute this thing doesnt make any sense here 
        # so we start off by importing the module and then getting the intial depsoit for each class we are going to 
        # need this when we create an obejct for each class to activate our class with and assuming that if we need 
        # different input its going to be taking care of it the second thing that we are doing is that we are getting 
        # different deposit amount and then different deposit amount to each class so that way we can call the method 
        # of withdraw or depoist and then define for each classes object how much we want to deposit and withdraw its 
        # important to understand that we are using the module.class(init) then use that obj and method and then the 
        # user input that has been modifed for each class and it is doing its own set of unique input once we do the 
        # depoist and then the withdraw we then get then print the object and thus doing so what happens is that we are 
        # getting the string value and then getting the object state and we do that for each class of the accounts 
        # overall this was a good beginners code to get started
